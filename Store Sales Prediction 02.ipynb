# %% [markdown]
# ## Import Packages and Data

# %%
#Import Package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.preprocessing import scale
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.metrics import mean_squared_log_error
from sklearn import preprocessing
import numpy as np
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from xgboost import plot_importance

# %%
#Import datasets
data_train = pd.read_csv('train.csv')
data_test = pd.read_csv('test.csv')
data_holidays = pd.read_csv('holidays_events.csv')
data_oil = pd.read_csv('oil.csv')
data_stores = pd.read_csv('stores.csv')

# %% [markdown]
# ## Check whether there are any NaN in the datasets

# %%
data_train.isnull().any()
# Out:
# id             False
# date           False
# store_nbr      False
# family         False
# sales          False
# onpromotion    False
# dtype: bool

# %%
data_test.isnull().any()
# Out:
# id             False
# date           False
# store_nbr      False
# family         False
# onpromotion    False
# dtype: bool

# %%
data_holidays.isnull().any()
# Out:
# date           False
# type           False
# locale         False
# locale_name    False
# description    False
# transferred    False
# dtype: bool

# %%
data_oil.isnull().any()
# Out:
# date          False
# dcoilwtico     True
# dtype: bool

# %%
#Fill the NaN with lastest price
data_oil_new = pd.DataFrame()
data_oil_new = data_oil
for i in range(len(data_oil_new)):
    if data_oil_new.iloc[i][1] > 0:
        pass
    elif i != 0:
        data_oil_new['dcoilwtico'][i] = data_oil_new['dcoilwtico'][i-1]
data_oil_new['dcoilwtico'][0] = data_oil_new['dcoilwtico'][1]
# Out:
# C:\Users\gbphw\AppData\Local\Temp\ipykernel_20912\3181917605.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_oil_new['dcoilwtico'][i] = data_oil_new['dcoilwtico'][i-1]
# C:\Users\gbphw\AppData\Local\Temp\ipykernel_20912\3181917605.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_oil_new['dcoilwtico'][0] = data_oil_new['dcoilwtico'][1]

# %%
data_oil_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1218 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
data_stores.isnull().any()
# Out:
# store_nbr    False
# city         False
# state        False
# type         False
# cluster      False
# dtype: bool

# %%
data_holidays["locale"].value_counts()
# Out:
# National    174
# Local       152
# Regional     24
# Name: locale, dtype: int64

# %% [markdown]
# ## Merging Data into a Table

# %%
df_train = data_train
df_train = df_train.merge(data_oil_new, how='left', on = 'date')
data_stores['country'] = 'Ecuador' 
df_train = df_train.merge(data_stores, how='left', on = 'store_nbr')

# %%
df_test = data_test
df_test = df_test.merge(data_oil_new, how='left', on = 'date')
df_test = df_test.merge(data_stores, how='left', on = 'store_nbr')

# %%
data_holidays_country = data_holidays.rename({"locale_name":"country"}, axis='columns')
df_train = df_train.merge(data_holidays_country, how='left', on = ['date', 'country'] )

# %%
df_test = df_test.merge(data_holidays_country, how='left', on = ['date', 'country'] )

# %% [markdown]
# ## Transforming Data into the Right Format

# %%
df_train = df_train.drop(['country', 'type_y', 'description','transferred'], axis=1)
df_train['national_holiday'] = pd.get_dummies(df_train['locale'])
df_train = df_train.drop(['locale'], axis=1)

# %%
df_test = df_test.drop(['country', 'type_y', 'description','transferred'], axis=1)
df_test['national_holiday'] = 0
df_test = df_test.drop(['locale'], axis=1)

# %%
df_train = df_train.rename({"type_x" : "store_type"}, axis = 'columns')
df_test = df_test.rename({"type_x" : "store_type"}, axis = 'columns')

# %%
data_holidays_region = data_holidays.rename({"locale_name":"state"}, axis='columns')
df_train = df_train.merge(data_holidays_region, how='left', on = ['date', 'state'] )

# %%
df_test = df_test.merge(data_holidays_region, how='left', on = ['date', 'state'] )

# %%
df_train = df_train.drop(['type', 'description','transferred'], axis=1)
df_train['region_holiday'] = df_train['locale']=='Regional'
df_train = df_train.drop(['locale'], axis=1)

# %%
df_test = df_test.drop(['type', 'description','transferred'], axis=1)
df_test['region_holiday'] = df_test['locale']=='Regional'
df_test = df_test.drop(['locale'], axis=1)

# %%
data_holidays_city = data_holidays.rename({"locale_name":"city"}, axis='columns')
df_train = df_train.merge(data_holidays_city, how='left', on = ['date', 'city'] )
df_test = df_test.merge(data_holidays_city, how='left', on = ['date', 'city'] )

# %%
df_train = df_train.drop(['type', 'description','transferred'], axis=1)
df_train['city_holiday'] = df_train['locale']=='Local'
df_train = df_train.drop(['locale'], axis=1)

# %%
df_test = df_test.drop(['type', 'description','transferred'], axis=1)
df_test['city_holiday'] = df_test['locale']=='Local'
df_test = df_test.drop(['locale'], axis=1)

# %%
df_train = df_train.replace(to_replace = False, value =0)
df_train = df_train.replace(to_replace = True, value =1)

# %%
df_test = df_test.replace(to_replace = False, value =0)
df_test = df_test.replace(to_replace = True, value =1)

# %%
#df_train['holidays'] = (df_train["national_holiday"]>0) | (df_train["region_holiday"]>0) | (df_train["city_holiday"]>0)
#df_test['holidays'] = (df_test["national_holiday"]>0) | (df_test["region_holiday"]>0) | (df_test["city_holiday"]>0)

# %%
#df_train = df_train.replace(to_replace = False, value =0)
#df_train = df_train.replace(to_replace = True, value =1)
#df_test = df_test.replace(to_replace = False, value =0)
#df_test = df_test.replace(to_replace = True, value =1)

# %%
df_train
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3008275  3000883  2017-08-15          9                     POULTRY   438.133
# 3008276  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3008277  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3008278  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3008279  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion  dcoilwtico   city      state store_type  cluster  \
# 0                  0       93.14  Quito  Pichincha          D       13
# 1                  0       93.14  Quito  Pichincha          D       13
# 2                  0       93.14  Quito  Pichincha          D       13
# 3                  0       93.14  Quito  Pichincha          D       13
# 4                  0       93.14  Quito  Pichincha          D       13
# ...              ...         ...    ...        ...        ...      ...
# 3008275            0       47.57  Quito  Pichincha          B        6
# 3008276            1       47.57  Quito  Pichincha          B        6
# 3008277          148       47.57  Quito  Pichincha          B        6
# 3008278            8       47.57  Quito  Pichincha          B        6
# 3008279            0       47.57  Quito  Pichincha          B        6
#
#          national_holiday  region_holiday  city_holiday
# 0                       1               0             0
# 1                       1               0             0
# 2                       1               0             0
# 3                       1               0             0
# 4                       1               0             0
# ...                   ...             ...           ...
# 3008275                 0               0             0
# 3008276                 0               0             0
# 3008277                 0               0             0
# 3008278                 0               0             0
# 3008279                 0               0             0
#
# [3008280 rows x 14 columns]

# %% [markdown]
# Focus on data after 2017-01-01

# %%
df_train = df_train[df_train['date']>"2016-12-31"]

# %%
#Create month, day columns for train set
month_train=[]
day_train=[]
for i in range(len(df_train)):
    month_train.append(df_train.iloc[i][1][5:7])
    day_train.append(df_train.iloc[i][1][8:10])
df_train['month'] = month_train
df_train['day'] = day_train
# Out:
# C:\Users\gbphw\AppData\Local\Temp\ipykernel_20912\1865844059.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['month'] = month_train
# C:\Users\gbphw\AppData\Local\Temp\ipykernel_20912\1865844059.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['day'] = day_train

# %%
#Create month, day columns for test set
month_test=[]
day_test=[]
for i in range(len(df_test)):
    month_test.append(df_test.iloc[i][1][5:7])
    day_test.append(df_test.iloc[i][1][8:10])
df_test['month'] = month_test
df_test['day'] = day_test

# %%
df_train
# Out:
#               id        date  store_nbr                      family     sales  \
# 2603766  2596374  2017-01-01          1                  AUTOMOTIVE     0.000
# 2603767  2596375  2017-01-01          1                   BABY CARE     0.000
# 2603768  2596376  2017-01-01          1                      BEAUTY     0.000
# 2603769  2596377  2017-01-01          1                   BEVERAGES     0.000
# 2603770  2596378  2017-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3008275  3000883  2017-08-15          9                     POULTRY   438.133
# 3008276  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3008277  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3008278  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3008279  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion  dcoilwtico   city      state store_type  cluster  \
# 2603766            0         NaN  Quito  Pichincha          D       13
# 2603767            0         NaN  Quito  Pichincha          D       13
# 2603768            0         NaN  Quito  Pichincha          D       13
# 2603769            0         NaN  Quito  Pichincha          D       13
# 2603770            0         NaN  Quito  Pichincha          D       13
# ...              ...         ...    ...        ...        ...      ...
# 3008275            0       47.57  Quito  Pichincha          B        6
# 3008276            1       47.57  Quito  Pichincha          B        6
# 3008277          148       47.57  Quito  Pichincha          B        6
# 3008278            8       47.57  Quito  Pichincha          B        6
# 3008279            0       47.57  Quito  Pichincha          B        6
#
#          national_holiday  region_holiday  city_holiday month day
# 2603766                 1               0             0    01  01
# 2603767                 1               0             0    01  01
# 2603768                 1               0             0    01  01
# 2603769                 1               0             0    01  01
# 2603770                 1               0             0    01  01
# ...                   ...             ...           ...   ...  ..
# 3008275                 0               0             0    08  15
# 3008276                 0               0             0    08  15
# 3008277                 0               0             0    08  15
# 3008278                 0               0             0    08  15
# 3008279                 0               0             0    08  15
#
# [404514 rows x 16 columns]

# %%
df_test
# Out:
#             id        date  store_nbr                      family  \
# 0      3000888  2017-08-16          1                  AUTOMOTIVE
# 1      3000889  2017-08-16          1                   BABY CARE
# 2      3000890  2017-08-16          1                      BEAUTY
# 3      3000891  2017-08-16          1                   BEVERAGES
# 4      3000892  2017-08-16          1                       BOOKS
# ...        ...         ...        ...                         ...
# 28507  3029395  2017-08-31          9                     POULTRY
# 28508  3029396  2017-08-31          9              PREPARED FOODS
# 28509  3029397  2017-08-31          9                     PRODUCE
# 28510  3029398  2017-08-31          9  SCHOOL AND OFFICE SUPPLIES
# 28511  3029399  2017-08-31          9                     SEAFOOD
#
#        onpromotion  dcoilwtico   city      state store_type  cluster  \
# 0                0       46.80  Quito  Pichincha          D       13
# 1                0       46.80  Quito  Pichincha          D       13
# 2                2       46.80  Quito  Pichincha          D       13
# 3               20       46.80  Quito  Pichincha          D       13
# 4                0       46.80  Quito  Pichincha          D       13
# ...            ...         ...    ...        ...        ...      ...
# 28507            1       47.26  Quito  Pichincha          B        6
# 28508            0       47.26  Quito  Pichincha          B        6
# 28509            1       47.26  Quito  Pichincha          B        6
# 28510            9       47.26  Quito  Pichincha          B        6
# 28511            0       47.26  Quito  Pichincha          B        6
#
#        national_holiday  region_holiday  city_holiday month day
# 0                     0               0             0    08  16
# 1                     0               0             0    08  16
# 2                     0               0             0    08  16
# 3                     0               0             0    08  16
# 4                     0               0             0    08  16
# ...                 ...             ...           ...   ...  ..
# 28507                 0               0             0    08  31
# 28508                 0               0             0    08  31
# 28509                 0               0             0    08  31
# 28510                 0               0             0    08  31
# 28511                 0               0             0    08  31
#
# [28512 rows x 15 columns]

# %%
#Split train set into train set and validation set
data_train = df_train[df_train['date']<="2017-07-15"]
data_val = df_train[df_train['date']>"2017-07-15"]
data_test = df_test

# %% [markdown]
# ## Creating an Additional Column - Weekday

# %%
#Create weekday column for train set
train_date = []
for j in range(len(data_train)):
    train_date.append(datetime.strptime(data_train.iloc[j][1],"%Y-%m-%d"))
s_train_date = pd.Series(train_date)
s_train_date = s_train_date.dt.weekday
s_train_date = s_train_date.tolist()
data_train['weekday'] = s_train_date
# Out:
# C:\Users\gbphw\AppData\Local\Temp\ipykernel_20912\2011225616.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['weekday'] = s_train_date

# %%
#Create weekday column for validation set
val_date = []
for j in range(len(data_val)):
    val_date.append(datetime.strptime(data_val.iloc[j][1],"%Y-%m-%d"))
s_val_date = pd.Series(val_date)
s_val_date = s_val_date.dt.weekday
s_val_date = s_val_date.tolist()
data_val['weekday'] = s_val_date
# Out:
# C:\Users\gbphw\AppData\Local\Temp\ipykernel_20912\236884441.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_val['weekday'] = s_val_date

# %%
#Create weekday column for test set
test_date = []
for j in range(len(data_test)):
    test_date.append(datetime.strptime(data_test.iloc[j][1],"%Y-%m-%d"))
s_test_date = pd.Series(test_date)
s_test_date = s_test_date.dt.weekday
s_test_date = s_test_date.tolist()
data_test['weekday'] = s_test_date

# %%
#Drop duplicate columns
data_train = data_train.drop(['id'], axis=1)
data_val = data_val.drop(['id'], axis=1)
data_test = data_test.drop(['id'], axis=1)

# %%
X_train = data_train.drop(['sales'],axis=1)
y_train = data_train['sales']
X_val = data_val.drop(['sales'],axis=1)
y_val = data_val['sales']

# %%
X_train.isnull().any()
# Out:
# date                False
# store_nbr           False
# family              False
# onpromotion         False
# dcoilwtico           True
# city                False
# state               False
# store_type          False
# cluster             False
# national_holiday    False
# region_holiday      False
# city_holiday        False
# month               False
# day                 False
# weekday             False
# dtype: bool

# %% [markdown]
# ## Cleaining Oil Data

# %%
#Use average oil price to fill oil na in train set
train_oil_new = pd.DataFrame()
train_oil_new['date'] = data_train['date']
train_oil_new = train_oil_new.merge(data_oil_new, how='left', on = 'date')
train_oil_new['month'] = train_oil_new['date'].map(lambda x: int(x.replace('-', '')[:6]))
train_oil_new['month_avg'] = train_oil_new.groupby('month')['dcoilwtico'].transform('mean')
train_oil_new['tmp'] = train_oil_new['dcoilwtico'].map(np.isnan)
train_oil_new['month_avg'] = train_oil_new['tmp'] * train_oil_new['month_avg']
train_oil_new['dcoilwtico'].fillna(0, inplace=True)
train_oil_new['oil'] = train_oil_new['dcoilwtico'] + train_oil_new['month_avg']
train_oil_new = train_oil_new.drop(['month', 'month_avg', 'tmp','dcoilwtico'], axis=1)
train_oil = train_oil_new['oil'].tolist()
X_train['oil'] = train_oil

# %%
#Use average oil price to fill oil na in validation set
val_oil_new = pd.DataFrame()
val_oil_new['date'] = data_val['date']
val_oil_new = val_oil_new.merge(data_oil_new, how='left', on = 'date')
val_oil_new['month'] = val_oil_new['date'].map(lambda x: int(x.replace('-', '')[:6]))
val_oil_new['month_avg'] = val_oil_new.groupby('month')['dcoilwtico'].transform('mean')
val_oil_new['tmp'] = val_oil_new['dcoilwtico'].map(np.isnan)
val_oil_new['month_avg'] = val_oil_new['tmp'] * val_oil_new['month_avg']
val_oil_new['dcoilwtico'].fillna(0, inplace=True)
val_oil_new['oil'] = val_oil_new['dcoilwtico'] + val_oil_new['month_avg']
val_oil_new = val_oil_new.drop(['month', 'month_avg', 'tmp','dcoilwtico'], axis=1)
val_oil = val_oil_new['oil'].tolist()
X_val['oil'] = val_oil

# %%
#Use average oil price to fill oil na in test set
test_oil_new = pd.DataFrame()
test_oil_new['date'] = data_test['date']
test_oil_new = test_oil_new.merge(data_oil_new, how='left', on = 'date')
test_oil_new['month'] = test_oil_new['date'].map(lambda x: int(x.replace('-', '')[:6]))
test_oil_new['month_avg'] = test_oil_new.groupby('month')['dcoilwtico'].transform('mean')
test_oil_new['tmp'] = test_oil_new['dcoilwtico'].map(np.isnan)
test_oil_new['month_avg'] = test_oil_new['tmp'] * test_oil_new['month_avg']
test_oil_new['dcoilwtico'].fillna(0, inplace=True)
test_oil_new['oil'] = test_oil_new['dcoilwtico'] + test_oil_new['month_avg']
test_oil_new = test_oil_new.drop(['month', 'month_avg', 'tmp','dcoilwtico'], axis=1)
test_oil = test_oil_new['oil'].tolist()
data_test['oil'] = test_oil

# %%
X_train = X_train.drop(['dcoilwtico', 'date'], axis=1)
X_val = X_val.drop(['dcoilwtico', 'date'], axis=1)
data_test = data_test.drop(['dcoilwtico', 'date'], axis=1)

# %% [markdown]
# ## Transforming Categorical Data

# %%
#Apply labelencoder to deal with the categorize factors
cat_features = ['family', 'store_nbr', 'city', 'state', 'store_type', 'cluster']
for col in cat_features:
    le = LabelEncoder()
    X_train[col] = le.fit_transform(X_train[col])
    X_val[col] = le.fit_transform(X_val[col])
    data_test[col] = le.transform(data_test[col])

# %%
train_test_data = pd.concat([X_train,X_val])
train_test_data = pd.concat([train_test_data,data_test])

# %%
train_test_data
# Out:
#          store_nbr  family  onpromotion  city  state  store_type  cluster  \
# 2603766          0       0            0    18     12           3       12
# 2603767          0       1            0    18     12           3       12
# 2603768          0       2            0    18     12           3       12
# 2603769          0       3            0    18     12           3       12
# 2603770          0       4            0    18     12           3       12
# ...            ...     ...          ...   ...    ...         ...      ...
# 28507            8      28            1    18     12           1        5
# 28508            8      29            0    18     12           1        5
# 28509            8      30            1    18     12           1        5
# 28510            8      31            9    18     12           1        5
# 28511            8      32            0    18     12           1        5
#
#          national_holiday  region_holiday  city_holiday month day  weekday  \
# 2603766                 1               0             0    01  01        6
# 2603767                 1               0             0    01  01        6
# 2603768                 1               0             0    01  01        6
# 2603769                 1               0             0    01  01        6
# 2603770                 1               0             0    01  01        6
# ...                   ...             ...           ...   ...  ..      ...
# 28507                   0               0             0    08  31        3
# 28508                   0               0             0    08  31        3
# 28509                   0               0             0    08  31        3
# 28510                   0               0             0    08  31        3
# 28511                   0               0             0    08  31        3
#
#                oil
# 2603766  52.554091
# 2603767  52.554091
# 2603768  52.554091
# 2603769  52.554091
# 2603770  52.554091
# ...            ...
# 28507    47.260000
# 28508    47.260000
# 28509    47.260000
# 28510    47.260000
# 28511    47.260000
#
# [433026 rows x 14 columns]

# %%
train_test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 433026 entries, 2603766 to 28511
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   store_nbr         433026 non-null  int64
#  1   family            433026 non-null  int32
#  2   onpromotion       433026 non-null  int64
#  3   city              433026 non-null  int32
#  4   state             433026 non-null  int32
#  5   store_type        433026 non-null  int32
#  6   cluster           433026 non-null  int64
#  7   national_holiday  433026 non-null  int64
#  8   region_holiday    433026 non-null  int64
#  9   city_holiday      433026 non-null  int64
#  10  month             433026 non-null  object
#  11  day               433026 non-null  object
#  12  weekday           433026 non-null  int64
#  13  oil               433026 non-null  float64
# dtypes: float64(1), int32(4), int64(7), object(2)
# memory usage: 42.9+ MB

# %% [markdown]
# ## Transforming Date Data into Dummies Variables

# %%
#Create weekday, month, day dummy variables
#weekday_dummy = pd.get_dummies(train_test_data['weekday'], prefix ='weekday')
#month_dummy = pd.get_dummies(train_test_data['month'], prefix ='month')
#day_dummy = pd.get_dummies(train_test_data['day'], prefix ='day')

# %%
#train_test_data = pd.concat([train_test_data,weekday_dummy], axis =1)
#train_test_data = pd.concat([train_test_data,month_dummy], axis =1)
#train_test_data = pd.concat([train_test_data,day_dummy], axis =1)
#train_test_data = train_test_data.drop(['month', 'day','weekday'], axis=1)
train_test_data[["month","day"]] = train_test_data[["month","day"]].astype('int32')

# %%
train_test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 433026 entries, 2603766 to 28511
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   store_nbr         433026 non-null  int64
#  1   family            433026 non-null  int32
#  2   onpromotion       433026 non-null  int64
#  3   city              433026 non-null  int32
#  4   state             433026 non-null  int32
#  5   store_type        433026 non-null  int32
#  6   cluster           433026 non-null  int64
#  7   national_holiday  433026 non-null  int64
#  8   region_holiday    433026 non-null  int64
#  9   city_holiday      433026 non-null  int64
#  10  month             433026 non-null  int32
#  11  day               433026 non-null  int32
#  12  weekday           433026 non-null  int64
#  13  oil               433026 non-null  float64
# dtypes: float64(1), int32(6), int64(7)
# memory usage: 39.6 MB

# %%
train_test_data
# Out:
#          store_nbr  family  onpromotion  city  state  store_type  cluster  \
# 2603766          0       0            0    18     12           3       12
# 2603767          0       1            0    18     12           3       12
# 2603768          0       2            0    18     12           3       12
# 2603769          0       3            0    18     12           3       12
# 2603770          0       4            0    18     12           3       12
# ...            ...     ...          ...   ...    ...         ...      ...
# 28507            8      28            1    18     12           1        5
# 28508            8      29            0    18     12           1        5
# 28509            8      30            1    18     12           1        5
# 28510            8      31            9    18     12           1        5
# 28511            8      32            0    18     12           1        5
#
#          national_holiday  region_holiday  city_holiday  month  day  weekday  \
# 2603766                 1               0             0      1    1        6
# 2603767                 1               0             0      1    1        6
# 2603768                 1               0             0      1    1        6
# 2603769                 1               0             0      1    1        6
# 2603770                 1               0             0      1    1        6
# ...                   ...             ...           ...    ...  ...      ...
# 28507                   0               0             0      8   31        3
# 28508                   0               0             0      8   31        3
# 28509                   0               0             0      8   31        3
# 28510                   0               0             0      8   31        3
# 28511                   0               0             0      8   31        3
#
#                oil
# 2603766  52.554091
# 2603767  52.554091
# 2603768  52.554091
# 2603769  52.554091
# 2603770  52.554091
# ...            ...
# 28507    47.260000
# 28508    47.260000
# 28509    47.260000
# 28510    47.260000
# 28511    47.260000
#
# [433026 rows x 14 columns]

# %%
#Standardize the oil price 
ooil = train_test_data['oil'].tolist()
mean_oil = np.mean(ooil)
std_oil = np.std(ooil)
for i in range(len(ooil)):
    ooil[i] = (ooil[i]-mean_oil)/std_oil
train_test_data['oil'] = ooil

# %%
#scaler = MinMaxScaler()
#scaler.fit(train_test_data)
#train_test_data['oil'] = scaler.transform(train_test_data['oil'])

# %%
#Split dataset into train, validation, and test sets
X_train = train_test_data[:len(X_train)]
X_val = train_test_data[len(X_train):len(X_train)+len(X_val)]
X_test = train_test_data[len(X_train)+len(X_val):]

# %%
#Apply log to transfer the sales
y_train = np.log(y_train+1) 
y_val = np.log(y_val+1)

# %% [markdown]
# ## Building model

# %%
#Model XGBOOST
xgbr = xgb.XGBRegressor(n_estimators =10000, early_stopping_rounds = 1000, learning_rate = 0.01)
xgbr.fit(X_train,y_train,eval_set=[(X_train,y_train),(X_val,y_val)], eval_metric = 'rmse')
# Out:
# [0]	validation_0-rmse:3.95604	validation_1-rmse:3.97905
# [1]	validation_0-rmse:3.91969	validation_1-rmse:3.94292
# C:\Users\gbphw\anaconda3\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [2]	validation_0-rmse:3.88373	validation_1-rmse:3.90719
# [3]	validation_0-rmse:3.84816	validation_1-rmse:3.87185
# [4]	validation_0-rmse:3.81298	validation_1-rmse:3.83688
# [5]	validation_0-rmse:3.77818	validation_1-rmse:3.80234
# [6]	validation_0-rmse:3.74376	validation_1-rmse:3.76813
# [7]	validation_0-rmse:3.70970	validation_1-rmse:3.73427
# [8]	validation_0-rmse:3.67602	validation_1-rmse:3.70076
# [9]	validation_0-rmse:3.64271	validation_1-rmse:3.66768
# [10]	validation_0-rmse:3.60976	validation_1-rmse:3.63491
# [11]	validation_0-rmse:3.57717	validation_1-rmse:3.60251
# [12]	validation_0-rmse:3.54493	validation_1-rmse:3.57008
# [13]	validation_0-rmse:3.51306	validation_1-rmse:3.53844
# [14]	validation_0-rmse:3.48153	validation_1-rmse:3.50710
# [15]	validation_0-rmse:3.45035	validation_1-rmse:3.47585
# [16]	validation_0-rmse:3.41955	validation_1-rmse:3.44486
# [17]	validation_0-rmse:3.38893	validation_1-rmse:3.41430
# [18]	validation_0-rmse:3.35872	validation_1-rmse:3.38403
# [19]	validation_0-rmse:3.32883	validation_1-rmse:3.35384
# [20]	validation_0-rmse:3.29937	validation_1-rmse:3.32452
# [21]	validation_0-rmse:3.27014	validation_1-rmse:3.29523
# [22]	validation_0-rmse:3.24124	validation_1-rmse:3.26594
# [23]	validation_0-rmse:3.21266	validation_1-rmse:3.23692
# [24]	validation_0-rmse:3.18443	validation_1-rmse:3.20867
# [25]	validation_0-rmse:3.15654	validation_1-rmse:3.18103
# [26]	validation_0-rmse:3.12891	validation_1-rmse:3.15305
# [27]	validation_0-rmse:3.10159	validation_1-rmse:3.12554
# [28]	validation_0-rmse:3.07457	validation_1-rmse:3.09845
# [29]	validation_0-rmse:3.04785	validation_1-rmse:3.07129
# [30]	validation_0-rmse:3.02149	validation_1-rmse:3.04474
# [31]	validation_0-rmse:2.99537	validation_1-rmse:3.01853
# [32]	validation_0-rmse:2.96961	validation_1-rmse:2.99276
# [33]	validation_0-rmse:2.94408	validation_1-rmse:2.96707
# [34]	validation_0-rmse:2.91885	validation_1-rmse:2.94172
# [35]	validation_0-rmse:2.89390	validation_1-rmse:2.91674
# [36]	validation_0-rmse:2.86926	validation_1-rmse:2.89184
# [37]	validation_0-rmse:2.84489	validation_1-rmse:2.86758
# [38]	validation_0-rmse:2.82082	validation_1-rmse:2.84317
# [39]	validation_0-rmse:2.79705	validation_1-rmse:2.81949
# [40]	validation_0-rmse:2.77349	validation_1-rmse:2.79595
# [41]	validation_0-rmse:2.74998	validation_1-rmse:2.77229
# [42]	validation_0-rmse:2.72694	validation_1-rmse:2.74934
# [43]	validation_0-rmse:2.70417	validation_1-rmse:2.72654
# [44]	validation_0-rmse:2.68142	validation_1-rmse:2.70356
# [45]	validation_0-rmse:2.65917	validation_1-rmse:2.68138
# [46]	validation_0-rmse:2.63678	validation_1-rmse:2.65901
# [47]	validation_0-rmse:2.61501	validation_1-rmse:2.63723
# [48]	validation_0-rmse:2.59323	validation_1-rmse:2.61541
# [49]	validation_0-rmse:2.57195	validation_1-rmse:2.59388
# [50]	validation_0-rmse:2.55061	validation_1-rmse:2.57294
# [51]	validation_0-rmse:2.52978	validation_1-rmse:2.55186
# [52]	validation_0-rmse:2.50839	validation_1-rmse:2.53036
# [53]	validation_0-rmse:2.48783	validation_1-rmse:2.51002
# [54]	validation_0-rmse:2.46700	validation_1-rmse:2.48891
# [55]	validation_0-rmse:2.44642	validation_1-rmse:2.46834
# [56]	validation_0-rmse:2.42593	validation_1-rmse:2.44769
# [57]	validation_0-rmse:2.40566	validation_1-rmse:2.42722
# [58]	validation_0-rmse:2.38572	validation_1-rmse:2.40692
# [59]	validation_0-rmse:2.36603	validation_1-rmse:2.38705
# [60]	validation_0-rmse:2.34645	validation_1-rmse:2.36729
# [61]	validation_0-rmse:2.32720	validation_1-rmse:2.34797
# [62]	validation_0-rmse:2.30804	validation_1-rmse:2.32874
# [63]	validation_0-rmse:2.28924	validation_1-rmse:2.30960
# [64]	validation_0-rmse:2.27056	validation_1-rmse:2.29083
# [65]	validation_0-rmse:2.25219	validation_1-rmse:2.27235
# [66]	validation_0-rmse:2.23491	validation_1-rmse:2.25530
# [67]	validation_0-rmse:2.21681	validation_1-rmse:2.23712
# [68]	validation_0-rmse:2.19912	validation_1-rmse:2.21911
# [69]	validation_0-rmse:2.18144	validation_1-rmse:2.20138
# [70]	validation_0-rmse:2.16416	validation_1-rmse:2.18387
# [71]	validation_0-rmse:2.14667	validation_1-rmse:2.16636
# [72]	validation_0-rmse:2.12980	validation_1-rmse:2.14954
# [73]	validation_0-rmse:2.11299	validation_1-rmse:2.13275
# [74]	validation_0-rmse:2.09621	validation_1-rmse:2.11566
# [75]	validation_0-rmse:2.07982	validation_1-rmse:2.09927
# [76]	validation_0-rmse:2.06367	validation_1-rmse:2.08306
# [77]	validation_0-rmse:2.04768	validation_1-rmse:2.06707
# [78]	validation_0-rmse:2.03164	validation_1-rmse:2.05070
# [79]	validation_0-rmse:2.01598	validation_1-rmse:2.03497
# [80]	validation_0-rmse:2.00034	validation_1-rmse:2.01927
# [81]	validation_0-rmse:1.98509	validation_1-rmse:2.00403
# [82]	validation_0-rmse:1.97010	validation_1-rmse:1.98873
# [83]	validation_0-rmse:1.95490	validation_1-rmse:1.97344
# [84]	validation_0-rmse:1.94025	validation_1-rmse:1.95880
# [85]	validation_0-rmse:1.92525	validation_1-rmse:1.94376
# [86]	validation_0-rmse:1.91095	validation_1-rmse:1.92919
# [87]	validation_0-rmse:1.89655	validation_1-rmse:1.91475
# [88]	validation_0-rmse:1.88250	validation_1-rmse:1.90063
# [89]	validation_0-rmse:1.86830	validation_1-rmse:1.88616
# [90]	validation_0-rmse:1.85458	validation_1-rmse:1.87244
# [91]	validation_0-rmse:1.84118	validation_1-rmse:1.85911
# [92]	validation_0-rmse:1.82753	validation_1-rmse:1.84537
# [93]	validation_0-rmse:1.81399	validation_1-rmse:1.83156
# [94]	validation_0-rmse:1.80090	validation_1-rmse:1.81848
# [95]	validation_0-rmse:1.78784	validation_1-rmse:1.80522
# [96]	validation_0-rmse:1.77514	validation_1-rmse:1.79252
# [97]	validation_0-rmse:1.76239	validation_1-rmse:1.77950
# [98]	validation_0-rmse:1.74996	validation_1-rmse:1.76706
# [99]	validation_0-rmse:1.73782	validation_1-rmse:1.75496
# [100]	validation_0-rmse:1.72529	validation_1-rmse:1.74240
# [101]	validation_0-rmse:1.71316	validation_1-rmse:1.72990
# [102]	validation_0-rmse:1.70131	validation_1-rmse:1.71804
# [103]	validation_0-rmse:1.68977	validation_1-rmse:1.70655
# [104]	validation_0-rmse:1.67783	validation_1-rmse:1.69472
# [105]	validation_0-rmse:1.66648	validation_1-rmse:1.68340
# [106]	validation_0-rmse:1.65483	validation_1-rmse:1.67184
# [107]	validation_0-rmse:1.64379	validation_1-rmse:1.66080
# [108]	validation_0-rmse:1.63260	validation_1-rmse:1.64992
# [109]	validation_0-rmse:1.62139	validation_1-rmse:1.63886
# [110]	validation_0-rmse:1.61070	validation_1-rmse:1.62815
# [111]	validation_0-rmse:1.60024	validation_1-rmse:1.61795
# [112]	validation_0-rmse:1.58996	validation_1-rmse:1.60776
# [113]	validation_0-rmse:1.57990	validation_1-rmse:1.59772
# [114]	validation_0-rmse:1.56927	validation_1-rmse:1.58718
# [115]	validation_0-rmse:1.55930	validation_1-rmse:1.57762
# [116]	validation_0-rmse:1.54946	validation_1-rmse:1.56784
# [117]	validation_0-rmse:1.53980	validation_1-rmse:1.55824
# [118]	validation_0-rmse:1.53015	validation_1-rmse:1.54872
# [119]	validation_0-rmse:1.52077	validation_1-rmse:1.53937
# [120]	validation_0-rmse:1.51103	validation_1-rmse:1.52972
# [121]	validation_0-rmse:1.50184	validation_1-rmse:1.52062
# [122]	validation_0-rmse:1.49230	validation_1-rmse:1.51110
# [123]	validation_0-rmse:1.48317	validation_1-rmse:1.50217
# [124]	validation_0-rmse:1.47421	validation_1-rmse:1.49344
# [125]	validation_0-rmse:1.46514	validation_1-rmse:1.48452
# [126]	validation_0-rmse:1.45641	validation_1-rmse:1.47596
# [127]	validation_0-rmse:1.44778	validation_1-rmse:1.46749
# [128]	validation_0-rmse:1.43938	validation_1-rmse:1.45938
# [129]	validation_0-rmse:1.43112	validation_1-rmse:1.45115
# [130]	validation_0-rmse:1.42286	validation_1-rmse:1.44293
# [131]	validation_0-rmse:1.41477	validation_1-rmse:1.43511
# [132]	validation_0-rmse:1.40683	validation_1-rmse:1.42741
# [133]	validation_0-rmse:1.39820	validation_1-rmse:1.41844
# [134]	validation_0-rmse:1.38970	validation_1-rmse:1.40959
# [135]	validation_0-rmse:1.38136	validation_1-rmse:1.40096
# [136]	validation_0-rmse:1.37364	validation_1-rmse:1.39370
# [137]	validation_0-rmse:1.36599	validation_1-rmse:1.38645
# [138]	validation_0-rmse:1.35849	validation_1-rmse:1.37939
# [139]	validation_0-rmse:1.35109	validation_1-rmse:1.37244
# [140]	validation_0-rmse:1.34377	validation_1-rmse:1.36553
# [141]	validation_0-rmse:1.33660	validation_1-rmse:1.35876
# [142]	validation_0-rmse:1.32944	validation_1-rmse:1.35204
# [143]	validation_0-rmse:1.32243	validation_1-rmse:1.34548
# [144]	validation_0-rmse:1.31563	validation_1-rmse:1.33891
# [145]	validation_0-rmse:1.30857	validation_1-rmse:1.33157
# [146]	validation_0-rmse:1.30184	validation_1-rmse:1.32526
# [147]	validation_0-rmse:1.29520	validation_1-rmse:1.31903
# [148]	validation_0-rmse:1.28878	validation_1-rmse:1.31281
# [149]	validation_0-rmse:1.28209	validation_1-rmse:1.30589
# [150]	validation_0-rmse:1.27571	validation_1-rmse:1.29986
# [151]	validation_0-rmse:1.26924	validation_1-rmse:1.29297
# [152]	validation_0-rmse:1.26314	validation_1-rmse:1.28702
# [153]	validation_0-rmse:1.25704	validation_1-rmse:1.28130
# [154]	validation_0-rmse:1.25108	validation_1-rmse:1.27548
# [155]	validation_0-rmse:1.24483	validation_1-rmse:1.26890
# [156]	validation_0-rmse:1.23908	validation_1-rmse:1.26336
# [157]	validation_0-rmse:1.23325	validation_1-rmse:1.25733
# [158]	validation_0-rmse:1.22753	validation_1-rmse:1.25141
# [159]	validation_0-rmse:1.22161	validation_1-rmse:1.24519
# [160]	validation_0-rmse:1.21612	validation_1-rmse:1.23986
# [161]	validation_0-rmse:1.20994	validation_1-rmse:1.23358
# [162]	validation_0-rmse:1.20387	validation_1-rmse:1.22740
# [163]	validation_0-rmse:1.19787	validation_1-rmse:1.22109
# [164]	validation_0-rmse:1.19267	validation_1-rmse:1.21612
# [165]	validation_0-rmse:1.18748	validation_1-rmse:1.21123
# [166]	validation_0-rmse:1.18221	validation_1-rmse:1.20600
# [167]	validation_0-rmse:1.17650	validation_1-rmse:1.20023
# [168]	validation_0-rmse:1.17090	validation_1-rmse:1.19450
# [169]	validation_0-rmse:1.16608	validation_1-rmse:1.18986
# [170]	validation_0-rmse:1.16054	validation_1-rmse:1.18397
# [171]	validation_0-rmse:1.15511	validation_1-rmse:1.17826
# [172]	validation_0-rmse:1.15043	validation_1-rmse:1.17376
# [173]	validation_0-rmse:1.14518	validation_1-rmse:1.16841
# [174]	validation_0-rmse:1.14069	validation_1-rmse:1.16406
# [175]	validation_0-rmse:1.13550	validation_1-rmse:1.15852
# [176]	validation_0-rmse:1.13111	validation_1-rmse:1.15429
# [177]	validation_0-rmse:1.12606	validation_1-rmse:1.14885
# [178]	validation_0-rmse:1.12148	validation_1-rmse:1.14433
# [179]	validation_0-rmse:1.11727	validation_1-rmse:1.13997
# [180]	validation_0-rmse:1.11247	validation_1-rmse:1.13507
# [181]	validation_0-rmse:1.10766	validation_1-rmse:1.12990
# [182]	validation_0-rmse:1.10332	validation_1-rmse:1.12560
# [183]	validation_0-rmse:1.09821	validation_1-rmse:1.12024
# [184]	validation_0-rmse:1.09395	validation_1-rmse:1.11593
# [185]	validation_0-rmse:1.08898	validation_1-rmse:1.11066
# [186]	validation_0-rmse:1.08518	validation_1-rmse:1.10676
# [187]	validation_0-rmse:1.08091	validation_1-rmse:1.10252
# [188]	validation_0-rmse:1.07605	validation_1-rmse:1.09737
# [189]	validation_0-rmse:1.07197	validation_1-rmse:1.09322
# [190]	validation_0-rmse:1.06770	validation_1-rmse:1.08882
# [191]	validation_0-rmse:1.06383	validation_1-rmse:1.08493
# [192]	validation_0-rmse:1.05966	validation_1-rmse:1.08021
# [193]	validation_0-rmse:1.05606	validation_1-rmse:1.07655
# [194]	validation_0-rmse:1.05216	validation_1-rmse:1.07274
# [195]	validation_0-rmse:1.04760	validation_1-rmse:1.06788
# [196]	validation_0-rmse:1.04393	validation_1-rmse:1.06415
# [197]	validation_0-rmse:1.03957	validation_1-rmse:1.05951
# [198]	validation_0-rmse:1.03617	validation_1-rmse:1.05595
# [199]	validation_0-rmse:1.03241	validation_1-rmse:1.05242
# [200]	validation_0-rmse:1.02821	validation_1-rmse:1.04806
# [201]	validation_0-rmse:1.02469	validation_1-rmse:1.04459
# [202]	validation_0-rmse:1.02125	validation_1-rmse:1.04120
# [203]	validation_0-rmse:1.01768	validation_1-rmse:1.03772
# [204]	validation_0-rmse:1.01359	validation_1-rmse:1.03340
# [205]	validation_0-rmse:1.01010	validation_1-rmse:1.02997
# [206]	validation_0-rmse:1.00668	validation_1-rmse:1.02664
# [207]	validation_0-rmse:1.00272	validation_1-rmse:1.02241
# [208]	validation_0-rmse:0.99943	validation_1-rmse:1.01923
# [209]	validation_0-rmse:0.99622	validation_1-rmse:1.01602
# [210]	validation_0-rmse:0.99251	validation_1-rmse:1.01197
# [211]	validation_0-rmse:0.98933	validation_1-rmse:1.00884
# [212]	validation_0-rmse:0.98627	validation_1-rmse:1.00572
# [213]	validation_0-rmse:0.98269	validation_1-rmse:1.00180
# [214]	validation_0-rmse:0.97937	validation_1-rmse:0.99789
# [215]	validation_0-rmse:0.97637	validation_1-rmse:0.99491
# [216]	validation_0-rmse:0.97350	validation_1-rmse:0.99201
# [217]	validation_0-rmse:0.97031	validation_1-rmse:0.98824
# [218]	validation_0-rmse:0.96752	validation_1-rmse:0.98544
# [219]	validation_0-rmse:0.96477	validation_1-rmse:0.98271
# [220]	validation_0-rmse:0.96168	validation_1-rmse:0.97905
# [221]	validation_0-rmse:0.95914	validation_1-rmse:0.97647
# [222]	validation_0-rmse:0.95647	validation_1-rmse:0.97384
# [223]	validation_0-rmse:0.95349	validation_1-rmse:0.97032
# [224]	validation_0-rmse:0.95091	validation_1-rmse:0.96773
# [225]	validation_0-rmse:0.94840	validation_1-rmse:0.96521
# [226]	validation_0-rmse:0.94553	validation_1-rmse:0.96180
# [227]	validation_0-rmse:0.94307	validation_1-rmse:0.95933
# [228]	validation_0-rmse:0.94033	validation_1-rmse:0.95639
# [229]	validation_0-rmse:0.93816	validation_1-rmse:0.95417
# [230]	validation_0-rmse:0.93576	validation_1-rmse:0.95179
# [231]	validation_0-rmse:0.93278	validation_1-rmse:0.94850
# [232]	validation_0-rmse:0.93047	validation_1-rmse:0.94620
# [233]	validation_0-rmse:0.92819	validation_1-rmse:0.94380
# [234]	validation_0-rmse:0.92531	validation_1-rmse:0.94059
# [235]	validation_0-rmse:0.92263	validation_1-rmse:0.93789
# [236]	validation_0-rmse:0.92005	validation_1-rmse:0.93478
# [237]	validation_0-rmse:0.91812	validation_1-rmse:0.93264
# [238]	validation_0-rmse:0.91610	validation_1-rmse:0.93057
# [239]	validation_0-rmse:0.91402	validation_1-rmse:0.92850
# [240]	validation_0-rmse:0.91195	validation_1-rmse:0.92638
# [241]	validation_0-rmse:0.90932	validation_1-rmse:0.92341
# [242]	validation_0-rmse:0.90680	validation_1-rmse:0.92088
# [243]	validation_0-rmse:0.90432	validation_1-rmse:0.91842
# [244]	validation_0-rmse:0.90195	validation_1-rmse:0.91552
# [245]	validation_0-rmse:0.90008	validation_1-rmse:0.91347
# [246]	validation_0-rmse:0.89816	validation_1-rmse:0.91150
# [247]	validation_0-rmse:0.89578	validation_1-rmse:0.90916
# [248]	validation_0-rmse:0.89350	validation_1-rmse:0.90636
# [249]	validation_0-rmse:0.89183	validation_1-rmse:0.90459
# [250]	validation_0-rmse:0.89004	validation_1-rmse:0.90284
# [251]	validation_0-rmse:0.88819	validation_1-rmse:0.90103
# [252]	validation_0-rmse:0.88641	validation_1-rmse:0.89916
# [253]	validation_0-rmse:0.88412	validation_1-rmse:0.89686
# [254]	validation_0-rmse:0.88177	validation_1-rmse:0.89462
# [255]	validation_0-rmse:0.88008	validation_1-rmse:0.89283
# [256]	validation_0-rmse:0.87836	validation_1-rmse:0.89112
# [257]	validation_0-rmse:0.87640	validation_1-rmse:0.88912
# [258]	validation_0-rmse:0.87422	validation_1-rmse:0.88694
# [259]	validation_0-rmse:0.87218	validation_1-rmse:0.88517
# [260]	validation_0-rmse:0.87063	validation_1-rmse:0.88360
# [261]	validation_0-rmse:0.86890	validation_1-rmse:0.88164
# [262]	validation_0-rmse:0.86731	validation_1-rmse:0.88008
# [263]	validation_0-rmse:0.86525	validation_1-rmse:0.87805
# [264]	validation_0-rmse:0.86312	validation_1-rmse:0.87603
# [265]	validation_0-rmse:0.86112	validation_1-rmse:0.87405
# [266]	validation_0-rmse:0.85923	validation_1-rmse:0.87244
# [267]	validation_0-rmse:0.85780	validation_1-rmse:0.87100
# [268]	validation_0-rmse:0.85620	validation_1-rmse:0.86878
# [269]	validation_0-rmse:0.85478	validation_1-rmse:0.86736
# [270]	validation_0-rmse:0.85297	validation_1-rmse:0.86586
# [271]	validation_0-rmse:0.85161	validation_1-rmse:0.86451
# [272]	validation_0-rmse:0.85011	validation_1-rmse:0.86275
# [273]	validation_0-rmse:0.84864	validation_1-rmse:0.86104
# [274]	validation_0-rmse:0.84678	validation_1-rmse:0.85916
# [275]	validation_0-rmse:0.84548	validation_1-rmse:0.85787
# [276]	validation_0-rmse:0.84368	validation_1-rmse:0.85605
# [277]	validation_0-rmse:0.84201	validation_1-rmse:0.85466
# [278]	validation_0-rmse:0.84030	validation_1-rmse:0.85239
# [279]	validation_0-rmse:0.83903	validation_1-rmse:0.85116
# [280]	validation_0-rmse:0.83741	validation_1-rmse:0.84979
# [281]	validation_0-rmse:0.83617	validation_1-rmse:0.84862
# [282]	validation_0-rmse:0.83481	validation_1-rmse:0.84703
# [283]	validation_0-rmse:0.83317	validation_1-rmse:0.84484
# [284]	validation_0-rmse:0.83198	validation_1-rmse:0.84369
# [285]	validation_0-rmse:0.83044	validation_1-rmse:0.84245
# [286]	validation_0-rmse:0.82931	validation_1-rmse:0.84134
# [287]	validation_0-rmse:0.82800	validation_1-rmse:0.83983
# [288]	validation_0-rmse:0.82644	validation_1-rmse:0.83774
# [289]	validation_0-rmse:0.82531	validation_1-rmse:0.83667
# [290]	validation_0-rmse:0.82385	validation_1-rmse:0.83545
# [291]	validation_0-rmse:0.82273	validation_1-rmse:0.83439
# [292]	validation_0-rmse:0.82131	validation_1-rmse:0.83324
# [293]	validation_0-rmse:0.82009	validation_1-rmse:0.83181
# [294]	validation_0-rmse:0.81897	validation_1-rmse:0.83076
# [295]	validation_0-rmse:0.81778	validation_1-rmse:0.82936
# [296]	validation_0-rmse:0.81623	validation_1-rmse:0.82781
# [297]	validation_0-rmse:0.81474	validation_1-rmse:0.82630
# [298]	validation_0-rmse:0.81315	validation_1-rmse:0.82484
# [299]	validation_0-rmse:0.81212	validation_1-rmse:0.82386
# [300]	validation_0-rmse:0.81066	validation_1-rmse:0.82236
# [301]	validation_0-rmse:0.80937	validation_1-rmse:0.82136
# [302]	validation_0-rmse:0.80823	validation_1-rmse:0.82028
# [303]	validation_0-rmse:0.80684	validation_1-rmse:0.81856
# [304]	validation_0-rmse:0.80551	validation_1-rmse:0.81687
# [305]	validation_0-rmse:0.80465	validation_1-rmse:0.81601
# [306]	validation_0-rmse:0.80328	validation_1-rmse:0.81432
# [307]	validation_0-rmse:0.80244	validation_1-rmse:0.81349
# [308]	validation_0-rmse:0.80160	validation_1-rmse:0.81266
# [309]	validation_0-rmse:0.80033	validation_1-rmse:0.81102
# [310]	validation_0-rmse:0.79923	validation_1-rmse:0.81017
# [311]	validation_0-rmse:0.79803	validation_1-rmse:0.80925
# [312]	validation_0-rmse:0.79723	validation_1-rmse:0.80847
# [313]	validation_0-rmse:0.79623	validation_1-rmse:0.80771
# [314]	validation_0-rmse:0.79500	validation_1-rmse:0.80618
# [315]	validation_0-rmse:0.79381	validation_1-rmse:0.80524
# [316]	validation_0-rmse:0.79304	validation_1-rmse:0.80448
# [317]	validation_0-rmse:0.79184	validation_1-rmse:0.80356
# [318]	validation_0-rmse:0.79107	validation_1-rmse:0.80280
# [319]	validation_0-rmse:0.78990	validation_1-rmse:0.80132
# [320]	validation_0-rmse:0.78893	validation_1-rmse:0.80058
# [321]	validation_0-rmse:0.78784	validation_1-rmse:0.79976
# [322]	validation_0-rmse:0.78667	validation_1-rmse:0.79822
# [323]	validation_0-rmse:0.78593	validation_1-rmse:0.79748
# [324]	validation_0-rmse:0.78505	validation_1-rmse:0.79683
# [325]	validation_0-rmse:0.78436	validation_1-rmse:0.79614
# [326]	validation_0-rmse:0.78325	validation_1-rmse:0.79531
# [327]	validation_0-rmse:0.78212	validation_1-rmse:0.79386
# [328]	validation_0-rmse:0.78143	validation_1-rmse:0.79309
# [329]	validation_0-rmse:0.78060	validation_1-rmse:0.79249
# [330]	validation_0-rmse:0.77954	validation_1-rmse:0.79168
# [331]	validation_0-rmse:0.77847	validation_1-rmse:0.79030
# [332]	validation_0-rmse:0.77781	validation_1-rmse:0.78963
# [333]	validation_0-rmse:0.77700	validation_1-rmse:0.78901
# [334]	validation_0-rmse:0.77599	validation_1-rmse:0.78826
# [335]	validation_0-rmse:0.77536	validation_1-rmse:0.78765
# [336]	validation_0-rmse:0.77458	validation_1-rmse:0.78708
# [337]	validation_0-rmse:0.77355	validation_1-rmse:0.78570
# [338]	validation_0-rmse:0.77280	validation_1-rmse:0.78517
# [339]	validation_0-rmse:0.77187	validation_1-rmse:0.78448
# [340]	validation_0-rmse:0.77128	validation_1-rmse:0.78386
# [341]	validation_0-rmse:0.77029	validation_1-rmse:0.78259
# [342]	validation_0-rmse:0.76954	validation_1-rmse:0.78203
# [343]	validation_0-rmse:0.76889	validation_1-rmse:0.78138
# [344]	validation_0-rmse:0.76802	validation_1-rmse:0.78075
# [345]	validation_0-rmse:0.76704	validation_1-rmse:0.77949
# [346]	validation_0-rmse:0.76644	validation_1-rmse:0.77888
# [347]	validation_0-rmse:0.76557	validation_1-rmse:0.77824
# [348]	validation_0-rmse:0.76498	validation_1-rmse:0.77763
# [349]	validation_0-rmse:0.76415	validation_1-rmse:0.77702
# [350]	validation_0-rmse:0.76357	validation_1-rmse:0.77643
# [351]	validation_0-rmse:0.76264	validation_1-rmse:0.77524
# [352]	validation_0-rmse:0.76208	validation_1-rmse:0.77466
# [353]	validation_0-rmse:0.76121	validation_1-rmse:0.77402
# [354]	validation_0-rmse:0.76066	validation_1-rmse:0.77348
# [355]	validation_0-rmse:0.76003	validation_1-rmse:0.77306
# [356]	validation_0-rmse:0.75915	validation_1-rmse:0.77184
# [357]	validation_0-rmse:0.75860	validation_1-rmse:0.77127
# [358]	validation_0-rmse:0.75794	validation_1-rmse:0.77080
# [359]	validation_0-rmse:0.75742	validation_1-rmse:0.77028
# [360]	validation_0-rmse:0.75678	validation_1-rmse:0.76986
# [361]	validation_0-rmse:0.75599	validation_1-rmse:0.76929
# [362]	validation_0-rmse:0.75514	validation_1-rmse:0.76809
# [363]	validation_0-rmse:0.75443	validation_1-rmse:0.76743
# [364]	validation_0-rmse:0.75374	validation_1-rmse:0.76677
# [365]	validation_0-rmse:0.75306	validation_1-rmse:0.76613
# [366]	validation_0-rmse:0.75240	validation_1-rmse:0.76551
# [367]	validation_0-rmse:0.75159	validation_1-rmse:0.76495
# [368]	validation_0-rmse:0.75078	validation_1-rmse:0.76440
# [369]	validation_0-rmse:0.75015	validation_1-rmse:0.76380
# [370]	validation_0-rmse:0.74949	validation_1-rmse:0.76332
# [371]	validation_0-rmse:0.74866	validation_1-rmse:0.76271
# [372]	validation_0-rmse:0.74805	validation_1-rmse:0.76213
# [373]	validation_0-rmse:0.74749	validation_1-rmse:0.76174
# [374]	validation_0-rmse:0.74685	validation_1-rmse:0.76114
# [375]	validation_0-rmse:0.74605	validation_1-rmse:0.76057
# [376]	validation_0-rmse:0.74542	validation_1-rmse:0.75998
# [377]	validation_0-rmse:0.74445	validation_1-rmse:0.75921
# [378]	validation_0-rmse:0.74384	validation_1-rmse:0.75862
# [379]	validation_0-rmse:0.74305	validation_1-rmse:0.75805
# [380]	validation_0-rmse:0.74245	validation_1-rmse:0.75749
# [381]	validation_0-rmse:0.74127	validation_1-rmse:0.75643
# [382]	validation_0-rmse:0.74070	validation_1-rmse:0.75589
# [383]	validation_0-rmse:0.73960	validation_1-rmse:0.75492
# [384]	validation_0-rmse:0.73870	validation_1-rmse:0.75410
# [385]	validation_0-rmse:0.73813	validation_1-rmse:0.75357
# [386]	validation_0-rmse:0.73754	validation_1-rmse:0.75316
# [387]	validation_0-rmse:0.73665	validation_1-rmse:0.75236
# [388]	validation_0-rmse:0.73610	validation_1-rmse:0.75186
# [389]	validation_0-rmse:0.73560	validation_1-rmse:0.75155
# [390]	validation_0-rmse:0.73474	validation_1-rmse:0.75075
# [391]	validation_0-rmse:0.73408	validation_1-rmse:0.75028
# [392]	validation_0-rmse:0.73323	validation_1-rmse:0.74952
# [393]	validation_0-rmse:0.73254	validation_1-rmse:0.74900
# [394]	validation_0-rmse:0.73201	validation_1-rmse:0.74852
# [395]	validation_0-rmse:0.73118	validation_1-rmse:0.74776
# [396]	validation_0-rmse:0.73055	validation_1-rmse:0.74728
# [397]	validation_0-rmse:0.72974	validation_1-rmse:0.74657
# [398]	validation_0-rmse:0.72922	validation_1-rmse:0.74612
# [399]	validation_0-rmse:0.72856	validation_1-rmse:0.74563
# [400]	validation_0-rmse:0.72805	validation_1-rmse:0.74517
# [401]	validation_0-rmse:0.72727	validation_1-rmse:0.74446
# [402]	validation_0-rmse:0.72665	validation_1-rmse:0.74399
# [403]	validation_0-rmse:0.72616	validation_1-rmse:0.74355
# [404]	validation_0-rmse:0.72539	validation_1-rmse:0.74285
# [405]	validation_0-rmse:0.72490	validation_1-rmse:0.74252
# [406]	validation_0-rmse:0.72430	validation_1-rmse:0.74209
# [407]	validation_0-rmse:0.72355	validation_1-rmse:0.74143
# [408]	validation_0-rmse:0.72307	validation_1-rmse:0.74099
# [409]	validation_0-rmse:0.72255	validation_1-rmse:0.74068
# [410]	validation_0-rmse:0.72181	validation_1-rmse:0.74001
# [411]	validation_0-rmse:0.72137	validation_1-rmse:0.73962
# [412]	validation_0-rmse:0.72085	validation_1-rmse:0.73931
# [413]	validation_0-rmse:0.72014	validation_1-rmse:0.73868
# [414]	validation_0-rmse:0.71954	validation_1-rmse:0.73822
# [415]	validation_0-rmse:0.71904	validation_1-rmse:0.73781
# [416]	validation_0-rmse:0.71857	validation_1-rmse:0.73755
# [417]	validation_0-rmse:0.71788	validation_1-rmse:0.73693
# [418]	validation_0-rmse:0.71719	validation_1-rmse:0.73633
# [419]	validation_0-rmse:0.71672	validation_1-rmse:0.73604
# [420]	validation_0-rmse:0.71605	validation_1-rmse:0.73544
# [421]	validation_0-rmse:0.71556	validation_1-rmse:0.73514
# [422]	validation_0-rmse:0.71491	validation_1-rmse:0.73458
# [423]	validation_0-rmse:0.71447	validation_1-rmse:0.73433
# [424]	validation_0-rmse:0.71383	validation_1-rmse:0.73375
# [425]	validation_0-rmse:0.71341	validation_1-rmse:0.73339
# [426]	validation_0-rmse:0.71295	validation_1-rmse:0.73313
# [427]	validation_0-rmse:0.71236	validation_1-rmse:0.73267
# [428]	validation_0-rmse:0.71189	validation_1-rmse:0.73237
# [429]	validation_0-rmse:0.71127	validation_1-rmse:0.73183
# [430]	validation_0-rmse:0.71087	validation_1-rmse:0.73160
# [431]	validation_0-rmse:0.71029	validation_1-rmse:0.73113
# [432]	validation_0-rmse:0.70985	validation_1-rmse:0.73086
# [433]	validation_0-rmse:0.70925	validation_1-rmse:0.73035
# [434]	validation_0-rmse:0.70886	validation_1-rmse:0.73002
# [435]	validation_0-rmse:0.70830	validation_1-rmse:0.72957
# [436]	validation_0-rmse:0.70775	validation_1-rmse:0.72912
# [437]	validation_0-rmse:0.70733	validation_1-rmse:0.72877
# [438]	validation_0-rmse:0.70693	validation_1-rmse:0.72854
# [439]	validation_0-rmse:0.70638	validation_1-rmse:0.72812
# [440]	validation_0-rmse:0.70575	validation_1-rmse:0.72752
# [441]	validation_0-rmse:0.70519	validation_1-rmse:0.72701
# [442]	validation_0-rmse:0.70481	validation_1-rmse:0.72668
# [443]	validation_0-rmse:0.70440	validation_1-rmse:0.72644
# [444]	validation_0-rmse:0.70387	validation_1-rmse:0.72603
# [445]	validation_0-rmse:0.70321	validation_1-rmse:0.72536
# [446]	validation_0-rmse:0.70282	validation_1-rmse:0.72503
# [447]	validation_0-rmse:0.70230	validation_1-rmse:0.72462
# [448]	validation_0-rmse:0.70192	validation_1-rmse:0.72442
# [449]	validation_0-rmse:0.70138	validation_1-rmse:0.72395
# [450]	validation_0-rmse:0.70100	validation_1-rmse:0.72361
# [451]	validation_0-rmse:0.70034	validation_1-rmse:0.72314
# [452]	validation_0-rmse:0.69985	validation_1-rmse:0.72275
# [453]	validation_0-rmse:0.69951	validation_1-rmse:0.72246
# [454]	validation_0-rmse:0.69913	validation_1-rmse:0.72225
# [455]	validation_0-rmse:0.69861	validation_1-rmse:0.72180
# [456]	validation_0-rmse:0.69802	validation_1-rmse:0.72124
# [457]	validation_0-rmse:0.69754	validation_1-rmse:0.72086
# [458]	validation_0-rmse:0.69717	validation_1-rmse:0.72055
# [459]	validation_0-rmse:0.69680	validation_1-rmse:0.72034
# [460]	validation_0-rmse:0.69633	validation_1-rmse:0.71997
# [461]	validation_0-rmse:0.69572	validation_1-rmse:0.71936
# [462]	validation_0-rmse:0.69536	validation_1-rmse:0.71904
# [463]	validation_0-rmse:0.69487	validation_1-rmse:0.71860
# [464]	validation_0-rmse:0.69450	validation_1-rmse:0.71841
# [465]	validation_0-rmse:0.69404	validation_1-rmse:0.71808
# [466]	validation_0-rmse:0.69344	validation_1-rmse:0.71739
# [467]	validation_0-rmse:0.69309	validation_1-rmse:0.71719
# [468]	validation_0-rmse:0.69262	validation_1-rmse:0.71677
# [469]	validation_0-rmse:0.69226	validation_1-rmse:0.71656
# [470]	validation_0-rmse:0.69182	validation_1-rmse:0.71623
# [471]	validation_0-rmse:0.69123	validation_1-rmse:0.71556
# [472]	validation_0-rmse:0.69064	validation_1-rmse:0.71515
# [473]	validation_0-rmse:0.69019	validation_1-rmse:0.71476
# [474]	validation_0-rmse:0.68961	validation_1-rmse:0.71410
# [475]	validation_0-rmse:0.68930	validation_1-rmse:0.71392
# [476]	validation_0-rmse:0.68887	validation_1-rmse:0.71360
# [477]	validation_0-rmse:0.68833	validation_1-rmse:0.71308
# [478]	validation_0-rmse:0.68789	validation_1-rmse:0.71269
# [479]	validation_0-rmse:0.68755	validation_1-rmse:0.71241
# [480]	validation_0-rmse:0.68715	validation_1-rmse:0.71211
# [481]	validation_0-rmse:0.68683	validation_1-rmse:0.71194
# [482]	validation_0-rmse:0.68643	validation_1-rmse:0.71163
# [483]	validation_0-rmse:0.68588	validation_1-rmse:0.71100
# [484]	validation_0-rmse:0.68537	validation_1-rmse:0.71049
# [485]	validation_0-rmse:0.68495	validation_1-rmse:0.71014
# [486]	validation_0-rmse:0.68464	validation_1-rmse:0.70996
# [487]	validation_0-rmse:0.68410	validation_1-rmse:0.70935
# [488]	validation_0-rmse:0.68371	validation_1-rmse:0.70905
# [489]	validation_0-rmse:0.68341	validation_1-rmse:0.70888
# [490]	validation_0-rmse:0.68289	validation_1-rmse:0.70829
# [491]	validation_0-rmse:0.68249	validation_1-rmse:0.70794
# [492]	validation_0-rmse:0.68220	validation_1-rmse:0.70777
# [493]	validation_0-rmse:0.68183	validation_1-rmse:0.70748
# [494]	validation_0-rmse:0.68153	validation_1-rmse:0.70731
# [495]	validation_0-rmse:0.68101	validation_1-rmse:0.70670
# [496]	validation_0-rmse:0.68063	validation_1-rmse:0.70637
# [497]	validation_0-rmse:0.68032	validation_1-rmse:0.70619
# [498]	validation_0-rmse:0.67997	validation_1-rmse:0.70592
# [499]	validation_0-rmse:0.67946	validation_1-rmse:0.70534
# [500]	validation_0-rmse:0.67916	validation_1-rmse:0.70517
# [501]	validation_0-rmse:0.67877	validation_1-rmse:0.70483
# [502]	validation_0-rmse:0.67823	validation_1-rmse:0.70447
# [503]	validation_0-rmse:0.67786	validation_1-rmse:0.70416
# [504]	validation_0-rmse:0.67736	validation_1-rmse:0.70358
# [505]	validation_0-rmse:0.67701	validation_1-rmse:0.70329
# [506]	validation_0-rmse:0.67672	validation_1-rmse:0.70311
# [507]	validation_0-rmse:0.67637	validation_1-rmse:0.70283
# [508]	validation_0-rmse:0.67588	validation_1-rmse:0.70226
# [509]	validation_0-rmse:0.67560	validation_1-rmse:0.70209
# [510]	validation_0-rmse:0.67532	validation_1-rmse:0.70194
# [511]	validation_0-rmse:0.67499	validation_1-rmse:0.70169
# [512]	validation_0-rmse:0.67473	validation_1-rmse:0.70153
# [513]	validation_0-rmse:0.67434	validation_1-rmse:0.70120
# [514]	validation_0-rmse:0.67388	validation_1-rmse:0.70067
# [515]	validation_0-rmse:0.67359	validation_1-rmse:0.70050
# [516]	validation_0-rmse:0.67327	validation_1-rmse:0.70025
# [517]	validation_0-rmse:0.67305	validation_1-rmse:0.70014
# [518]	validation_0-rmse:0.67268	validation_1-rmse:0.69984
# [519]	validation_0-rmse:0.67223	validation_1-rmse:0.69932
# [520]	validation_0-rmse:0.67199	validation_1-rmse:0.69921
# [521]	validation_0-rmse:0.67166	validation_1-rmse:0.69893
# [522]	validation_0-rmse:0.67142	validation_1-rmse:0.69881
# [523]	validation_0-rmse:0.67110	validation_1-rmse:0.69856
# [524]	validation_0-rmse:0.67065	validation_1-rmse:0.69808
# [525]	validation_0-rmse:0.67017	validation_1-rmse:0.69766
# [526]	validation_0-rmse:0.66982	validation_1-rmse:0.69739
# [527]	validation_0-rmse:0.66938	validation_1-rmse:0.69687
# [528]	validation_0-rmse:0.66916	validation_1-rmse:0.69679
# [529]	validation_0-rmse:0.66858	validation_1-rmse:0.69631
# [530]	validation_0-rmse:0.66837	validation_1-rmse:0.69620
# [531]	validation_0-rmse:0.66807	validation_1-rmse:0.69597
# [532]	validation_0-rmse:0.66761	validation_1-rmse:0.69557
# [533]	validation_0-rmse:0.66733	validation_1-rmse:0.69535
# [534]	validation_0-rmse:0.66711	validation_1-rmse:0.69523
# [535]	validation_0-rmse:0.66600	validation_1-rmse:0.69370
# [536]	validation_0-rmse:0.66549	validation_1-rmse:0.69309
# [537]	validation_0-rmse:0.66494	validation_1-rmse:0.69262
# [538]	validation_0-rmse:0.66473	validation_1-rmse:0.69253
# [539]	validation_0-rmse:0.66439	validation_1-rmse:0.69213
# [540]	validation_0-rmse:0.66419	validation_1-rmse:0.69206
# [541]	validation_0-rmse:0.66364	validation_1-rmse:0.69159
# [542]	validation_0-rmse:0.66319	validation_1-rmse:0.69129
# [543]	validation_0-rmse:0.66275	validation_1-rmse:0.69090
# [544]	validation_0-rmse:0.66246	validation_1-rmse:0.69068
# [545]	validation_0-rmse:0.66212	validation_1-rmse:0.69029
# [546]	validation_0-rmse:0.66190	validation_1-rmse:0.69018
# [547]	validation_0-rmse:0.66149	validation_1-rmse:0.68985
# [548]	validation_0-rmse:0.66120	validation_1-rmse:0.68952
# [549]	validation_0-rmse:0.66101	validation_1-rmse:0.68939
# [550]	validation_0-rmse:0.66051	validation_1-rmse:0.68895
# [551]	validation_0-rmse:0.66010	validation_1-rmse:0.68862
# [552]	validation_0-rmse:0.65992	validation_1-rmse:0.68853
# [553]	validation_0-rmse:0.65963	validation_1-rmse:0.68820
# [554]	validation_0-rmse:0.65945	validation_1-rmse:0.68811
# [555]	validation_0-rmse:0.65875	validation_1-rmse:0.68738
# [556]	validation_0-rmse:0.65800	validation_1-rmse:0.68669
# [557]	validation_0-rmse:0.65781	validation_1-rmse:0.68657
# [558]	validation_0-rmse:0.65714	validation_1-rmse:0.68584
# [559]	validation_0-rmse:0.65640	validation_1-rmse:0.68516
# [560]	validation_0-rmse:0.65621	validation_1-rmse:0.68507
# [561]	validation_0-rmse:0.65548	validation_1-rmse:0.68440
# [562]	validation_0-rmse:0.65483	validation_1-rmse:0.68369
# [563]	validation_0-rmse:0.65465	validation_1-rmse:0.68356
# [564]	validation_0-rmse:0.65401	validation_1-rmse:0.68288
# [565]	validation_0-rmse:0.65382	validation_1-rmse:0.68270
# [566]	validation_0-rmse:0.65364	validation_1-rmse:0.68262
# [567]	validation_0-rmse:0.65293	validation_1-rmse:0.68198
# [568]	validation_0-rmse:0.65267	validation_1-rmse:0.68185
# [569]	validation_0-rmse:0.65221	validation_1-rmse:0.68140
# [570]	validation_0-rmse:0.65189	validation_1-rmse:0.68114
# [571]	validation_0-rmse:0.65172	validation_1-rmse:0.68105
# [572]	validation_0-rmse:0.65139	validation_1-rmse:0.68078
# [573]	validation_0-rmse:0.65114	validation_1-rmse:0.68064
# [574]	validation_0-rmse:0.65045	validation_1-rmse:0.68002
# [575]	validation_0-rmse:0.65019	validation_1-rmse:0.67982
# [576]	validation_0-rmse:0.65003	validation_1-rmse:0.67972
# [577]	validation_0-rmse:0.64938	validation_1-rmse:0.67899
# [578]	validation_0-rmse:0.64916	validation_1-rmse:0.67880
# [579]	validation_0-rmse:0.64898	validation_1-rmse:0.67871
# [580]	validation_0-rmse:0.64831	validation_1-rmse:0.67810
# [581]	validation_0-rmse:0.64800	validation_1-rmse:0.67788
# [582]	validation_0-rmse:0.64782	validation_1-rmse:0.67778
# [583]	validation_0-rmse:0.64757	validation_1-rmse:0.67758
# [584]	validation_0-rmse:0.64734	validation_1-rmse:0.67737
# [585]	validation_0-rmse:0.64719	validation_1-rmse:0.67727
# [586]	validation_0-rmse:0.64656	validation_1-rmse:0.67656
# [587]	validation_0-rmse:0.64635	validation_1-rmse:0.67638
# [588]	validation_0-rmse:0.64621	validation_1-rmse:0.67634
# [589]	validation_0-rmse:0.64596	validation_1-rmse:0.67615
# [590]	validation_0-rmse:0.64574	validation_1-rmse:0.67595
# [591]	validation_0-rmse:0.64558	validation_1-rmse:0.67586
# [592]	validation_0-rmse:0.64533	validation_1-rmse:0.67564
# [593]	validation_0-rmse:0.64509	validation_1-rmse:0.67545
# [594]	validation_0-rmse:0.64495	validation_1-rmse:0.67539
# [595]	validation_0-rmse:0.64475	validation_1-rmse:0.67525
# [596]	validation_0-rmse:0.64415	validation_1-rmse:0.67456
# [597]	validation_0-rmse:0.64394	validation_1-rmse:0.67437
# [598]	validation_0-rmse:0.64375	validation_1-rmse:0.67424
# [599]	validation_0-rmse:0.64351	validation_1-rmse:0.67403
# [600]	validation_0-rmse:0.64286	validation_1-rmse:0.67343
# [601]	validation_0-rmse:0.64272	validation_1-rmse:0.67335
# [602]	validation_0-rmse:0.64253	validation_1-rmse:0.67323
# [603]	validation_0-rmse:0.64225	validation_1-rmse:0.67303
# [604]	validation_0-rmse:0.64207	validation_1-rmse:0.67291
# [605]	validation_0-rmse:0.64183	validation_1-rmse:0.67267
# [606]	validation_0-rmse:0.64167	validation_1-rmse:0.67259
# [607]	validation_0-rmse:0.64144	validation_1-rmse:0.67241
# [608]	validation_0-rmse:0.64124	validation_1-rmse:0.67220
# [609]	validation_0-rmse:0.64107	validation_1-rmse:0.67211
# [610]	validation_0-rmse:0.64086	validation_1-rmse:0.67192
# [611]	validation_0-rmse:0.64072	validation_1-rmse:0.67185
# [612]	validation_0-rmse:0.64008	validation_1-rmse:0.67127
# [613]	validation_0-rmse:0.63951	validation_1-rmse:0.67062
# [614]	validation_0-rmse:0.63939	validation_1-rmse:0.67056
# [615]	validation_0-rmse:0.63916	validation_1-rmse:0.67039
# [616]	validation_0-rmse:0.63901	validation_1-rmse:0.67031
# [617]	validation_0-rmse:0.63881	validation_1-rmse:0.67013
# [618]	validation_0-rmse:0.63848	validation_1-rmse:0.66985
# [619]	validation_0-rmse:0.63834	validation_1-rmse:0.66978
# [620]	validation_0-rmse:0.63735	validation_1-rmse:0.66833
# [621]	validation_0-rmse:0.63709	validation_1-rmse:0.66812
# [622]	validation_0-rmse:0.63693	validation_1-rmse:0.66804
# [623]	validation_0-rmse:0.63677	validation_1-rmse:0.66789
# [624]	validation_0-rmse:0.63645	validation_1-rmse:0.66761
# [625]	validation_0-rmse:0.63629	validation_1-rmse:0.66751
# [626]	validation_0-rmse:0.63606	validation_1-rmse:0.66734
# [627]	validation_0-rmse:0.63579	validation_1-rmse:0.66708
# [628]	validation_0-rmse:0.63562	validation_1-rmse:0.66695
# [629]	validation_0-rmse:0.63531	validation_1-rmse:0.66667
# [630]	validation_0-rmse:0.63516	validation_1-rmse:0.66660
# [631]	validation_0-rmse:0.63499	validation_1-rmse:0.66651
# [632]	validation_0-rmse:0.63443	validation_1-rmse:0.66590
# [633]	validation_0-rmse:0.63426	validation_1-rmse:0.66575
# [634]	validation_0-rmse:0.63403	validation_1-rmse:0.66556
# [635]	validation_0-rmse:0.63383	validation_1-rmse:0.66539
# [636]	validation_0-rmse:0.63362	validation_1-rmse:0.66522
# [637]	validation_0-rmse:0.63280	validation_1-rmse:0.66419
# [638]	validation_0-rmse:0.63257	validation_1-rmse:0.66400
# [639]	validation_0-rmse:0.63198	validation_1-rmse:0.66346
# [640]	validation_0-rmse:0.63182	validation_1-rmse:0.66335
# [641]	validation_0-rmse:0.63161	validation_1-rmse:0.66320
# [642]	validation_0-rmse:0.63083	validation_1-rmse:0.66220
# [643]	validation_0-rmse:0.63023	validation_1-rmse:0.66167
# [644]	validation_0-rmse:0.63012	validation_1-rmse:0.66162
# [645]	validation_0-rmse:0.62991	validation_1-rmse:0.66146
# [646]	validation_0-rmse:0.62910	validation_1-rmse:0.66018
# [647]	validation_0-rmse:0.62854	validation_1-rmse:0.65965
# [648]	validation_0-rmse:0.62834	validation_1-rmse:0.65948
# [649]	validation_0-rmse:0.62779	validation_1-rmse:0.65901
# [650]	validation_0-rmse:0.62756	validation_1-rmse:0.65883
# [651]	validation_0-rmse:0.62737	validation_1-rmse:0.65867
# [652]	validation_0-rmse:0.62657	validation_1-rmse:0.65740
# [653]	validation_0-rmse:0.62603	validation_1-rmse:0.65692
# [654]	validation_0-rmse:0.62583	validation_1-rmse:0.65676
# [655]	validation_0-rmse:0.62565	validation_1-rmse:0.65661
# [656]	validation_0-rmse:0.62512	validation_1-rmse:0.65617
# [657]	validation_0-rmse:0.62435	validation_1-rmse:0.65494
# [658]	validation_0-rmse:0.62416	validation_1-rmse:0.65481
# [659]	validation_0-rmse:0.62398	validation_1-rmse:0.65468
# [660]	validation_0-rmse:0.62346	validation_1-rmse:0.65425
# [661]	validation_0-rmse:0.62326	validation_1-rmse:0.65409
# [662]	validation_0-rmse:0.62242	validation_1-rmse:0.65274
# [663]	validation_0-rmse:0.62192	validation_1-rmse:0.65228
# [664]	validation_0-rmse:0.62177	validation_1-rmse:0.65218
# [665]	validation_0-rmse:0.62152	validation_1-rmse:0.65197
# [666]	validation_0-rmse:0.62136	validation_1-rmse:0.65185
# [667]	validation_0-rmse:0.62116	validation_1-rmse:0.65169
# [668]	validation_0-rmse:0.62034	validation_1-rmse:0.65037
# [669]	validation_0-rmse:0.61980	validation_1-rmse:0.64992
# [670]	validation_0-rmse:0.61955	validation_1-rmse:0.64973
# [671]	validation_0-rmse:0.61939	validation_1-rmse:0.64961
# [672]	validation_0-rmse:0.61852	validation_1-rmse:0.64820
# [673]	validation_0-rmse:0.61800	validation_1-rmse:0.64773
# [674]	validation_0-rmse:0.61754	validation_1-rmse:0.64723
# [675]	validation_0-rmse:0.61705	validation_1-rmse:0.64683
# [676]	validation_0-rmse:0.61695	validation_1-rmse:0.64679
# [677]	validation_0-rmse:0.61671	validation_1-rmse:0.64661
# [678]	validation_0-rmse:0.61653	validation_1-rmse:0.64648
# [679]	validation_0-rmse:0.61633	validation_1-rmse:0.64632
# [680]	validation_0-rmse:0.61557	validation_1-rmse:0.64502
# [681]	validation_0-rmse:0.61533	validation_1-rmse:0.64484
# [682]	validation_0-rmse:0.61515	validation_1-rmse:0.64470
# [683]	validation_0-rmse:0.61440	validation_1-rmse:0.64341
# [684]	validation_0-rmse:0.61417	validation_1-rmse:0.64322
# [685]	validation_0-rmse:0.61407	validation_1-rmse:0.64318
# [686]	validation_0-rmse:0.61392	validation_1-rmse:0.64307
# [687]	validation_0-rmse:0.61369	validation_1-rmse:0.64290
# [688]	validation_0-rmse:0.61355	validation_1-rmse:0.64280
# [689]	validation_0-rmse:0.61282	validation_1-rmse:0.64154
# [690]	validation_0-rmse:0.61259	validation_1-rmse:0.64137
# [691]	validation_0-rmse:0.61240	validation_1-rmse:0.64122
# [692]	validation_0-rmse:0.61168	validation_1-rmse:0.63999
# [693]	validation_0-rmse:0.61145	validation_1-rmse:0.63978
# [694]	validation_0-rmse:0.61131	validation_1-rmse:0.63970
# [695]	validation_0-rmse:0.61109	validation_1-rmse:0.63953
# [696]	validation_0-rmse:0.61046	validation_1-rmse:0.63859
# [697]	validation_0-rmse:0.61030	validation_1-rmse:0.63847
# [698]	validation_0-rmse:0.60984	validation_1-rmse:0.63809
# [699]	validation_0-rmse:0.60905	validation_1-rmse:0.63681
# [700]	validation_0-rmse:0.60873	validation_1-rmse:0.63649
# [701]	validation_0-rmse:0.60857	validation_1-rmse:0.63635
# [702]	validation_0-rmse:0.60847	validation_1-rmse:0.63631
# [703]	validation_0-rmse:0.60833	validation_1-rmse:0.63622
# [704]	validation_0-rmse:0.60819	validation_1-rmse:0.63613
# [705]	validation_0-rmse:0.60741	validation_1-rmse:0.63488
# [706]	validation_0-rmse:0.60726	validation_1-rmse:0.63475
# [707]	validation_0-rmse:0.60706	validation_1-rmse:0.63461
# [708]	validation_0-rmse:0.60691	validation_1-rmse:0.63448
# [709]	validation_0-rmse:0.60677	validation_1-rmse:0.63436
# [710]	validation_0-rmse:0.60611	validation_1-rmse:0.63320
# [711]	validation_0-rmse:0.60597	validation_1-rmse:0.63308
# [712]	validation_0-rmse:0.60577	validation_1-rmse:0.63295
# [713]	validation_0-rmse:0.60512	validation_1-rmse:0.63195
# [714]	validation_0-rmse:0.60498	validation_1-rmse:0.63183
# [715]	validation_0-rmse:0.60480	validation_1-rmse:0.63172
# [716]	validation_0-rmse:0.60466	validation_1-rmse:0.63163
# [717]	validation_0-rmse:0.60402	validation_1-rmse:0.63051
# [718]	validation_0-rmse:0.60387	validation_1-rmse:0.63038
# [719]	validation_0-rmse:0.60378	validation_1-rmse:0.63034
# [720]	validation_0-rmse:0.60364	validation_1-rmse:0.63012
# [721]	validation_0-rmse:0.60303	validation_1-rmse:0.62915
# [722]	validation_0-rmse:0.60285	validation_1-rmse:0.62904
# [723]	validation_0-rmse:0.60272	validation_1-rmse:0.62893
# [724]	validation_0-rmse:0.60210	validation_1-rmse:0.62785
# [725]	validation_0-rmse:0.60192	validation_1-rmse:0.62775
# [726]	validation_0-rmse:0.60177	validation_1-rmse:0.62763
# [727]	validation_0-rmse:0.60164	validation_1-rmse:0.62755
# [728]	validation_0-rmse:0.60105	validation_1-rmse:0.62658
# [729]	validation_0-rmse:0.60091	validation_1-rmse:0.62646
# [730]	validation_0-rmse:0.60079	validation_1-rmse:0.62637
# [731]	validation_0-rmse:0.60020	validation_1-rmse:0.62544
# [732]	validation_0-rmse:0.60007	validation_1-rmse:0.62533
# [733]	validation_0-rmse:0.59986	validation_1-rmse:0.62512
# [734]	validation_0-rmse:0.59973	validation_1-rmse:0.62496
# [735]	validation_0-rmse:0.59960	validation_1-rmse:0.62485
# [736]	validation_0-rmse:0.59942	validation_1-rmse:0.62475
# [737]	validation_0-rmse:0.59933	validation_1-rmse:0.62471
# [738]	validation_0-rmse:0.59920	validation_1-rmse:0.62455
# [739]	validation_0-rmse:0.59909	validation_1-rmse:0.62447
# [740]	validation_0-rmse:0.59856	validation_1-rmse:0.62368
# [741]	validation_0-rmse:0.59839	validation_1-rmse:0.62357
# [742]	validation_0-rmse:0.59826	validation_1-rmse:0.62341
# [743]	validation_0-rmse:0.59812	validation_1-rmse:0.62330
# [744]	validation_0-rmse:0.59804	validation_1-rmse:0.62326
# [745]	validation_0-rmse:0.59784	validation_1-rmse:0.62306
# [746]	validation_0-rmse:0.59771	validation_1-rmse:0.62291
# [747]	validation_0-rmse:0.59754	validation_1-rmse:0.62281
# [748]	validation_0-rmse:0.59721	validation_1-rmse:0.62242
# [749]	validation_0-rmse:0.59709	validation_1-rmse:0.62227
# [750]	validation_0-rmse:0.59694	validation_1-rmse:0.62215
# [751]	validation_0-rmse:0.59686	validation_1-rmse:0.62212
# [752]	validation_0-rmse:0.59667	validation_1-rmse:0.62192
# [753]	validation_0-rmse:0.59650	validation_1-rmse:0.62182
# [754]	validation_0-rmse:0.59638	validation_1-rmse:0.62168
# [755]	validation_0-rmse:0.59622	validation_1-rmse:0.62158
# [756]	validation_0-rmse:0.59608	validation_1-rmse:0.62129
# [757]	validation_0-rmse:0.59597	validation_1-rmse:0.62121
# [758]	validation_0-rmse:0.59576	validation_1-rmse:0.62102
# [759]	validation_0-rmse:0.59563	validation_1-rmse:0.62091
# [760]	validation_0-rmse:0.59550	validation_1-rmse:0.62062
# [761]	validation_0-rmse:0.59533	validation_1-rmse:0.62051
# [762]	validation_0-rmse:0.59526	validation_1-rmse:0.62049
# [763]	validation_0-rmse:0.59494	validation_1-rmse:0.62008
# [764]	validation_0-rmse:0.59483	validation_1-rmse:0.62001
# [765]	validation_0-rmse:0.59470	validation_1-rmse:0.61972
# [766]	validation_0-rmse:0.59454	validation_1-rmse:0.61963
# [767]	validation_0-rmse:0.59402	validation_1-rmse:0.61890
# [768]	validation_0-rmse:0.59388	validation_1-rmse:0.61879
# [769]	validation_0-rmse:0.59376	validation_1-rmse:0.61851
# [770]	validation_0-rmse:0.59360	validation_1-rmse:0.61841
# [771]	validation_0-rmse:0.59334	validation_1-rmse:0.61805
# [772]	validation_0-rmse:0.59327	validation_1-rmse:0.61803
# [773]	validation_0-rmse:0.59273	validation_1-rmse:0.61727
# [774]	validation_0-rmse:0.59261	validation_1-rmse:0.61700
# [775]	validation_0-rmse:0.59246	validation_1-rmse:0.61690
# [776]	validation_0-rmse:0.59233	validation_1-rmse:0.61678
# [777]	validation_0-rmse:0.59213	validation_1-rmse:0.61662
# [778]	validation_0-rmse:0.59205	validation_1-rmse:0.61658
# [779]	validation_0-rmse:0.59193	validation_1-rmse:0.61631
# [780]	validation_0-rmse:0.59177	validation_1-rmse:0.61622
# [781]	validation_0-rmse:0.59127	validation_1-rmse:0.61551
# [782]	validation_0-rmse:0.59115	validation_1-rmse:0.61525
# [783]	validation_0-rmse:0.59103	validation_1-rmse:0.61515
# [784]	validation_0-rmse:0.59054	validation_1-rmse:0.61446
# [785]	validation_0-rmse:0.59039	validation_1-rmse:0.61436
# [786]	validation_0-rmse:0.59026	validation_1-rmse:0.61425
# [787]	validation_0-rmse:0.59015	validation_1-rmse:0.61400
# [788]	validation_0-rmse:0.59004	validation_1-rmse:0.61393
# [789]	validation_0-rmse:0.58989	validation_1-rmse:0.61383
# [790]	validation_0-rmse:0.58958	validation_1-rmse:0.61347
# [791]	validation_0-rmse:0.58946	validation_1-rmse:0.61335
# [792]	validation_0-rmse:0.58934	validation_1-rmse:0.61311
# [793]	validation_0-rmse:0.58927	validation_1-rmse:0.61307
# [794]	validation_0-rmse:0.58908	validation_1-rmse:0.61291
# [795]	validation_0-rmse:0.58894	validation_1-rmse:0.61282
# [796]	validation_0-rmse:0.58884	validation_1-rmse:0.61258
# [797]	validation_0-rmse:0.58835	validation_1-rmse:0.61191
# [798]	validation_0-rmse:0.58822	validation_1-rmse:0.61180
# [799]	validation_0-rmse:0.58811	validation_1-rmse:0.61173
# [800]	validation_0-rmse:0.58800	validation_1-rmse:0.61148
# [801]	validation_0-rmse:0.58752	validation_1-rmse:0.61082
# [802]	validation_0-rmse:0.58741	validation_1-rmse:0.61072
# [803]	validation_0-rmse:0.58726	validation_1-rmse:0.61063
# [804]	validation_0-rmse:0.58718	validation_1-rmse:0.61059
# [805]	validation_0-rmse:0.58708	validation_1-rmse:0.61036
# [806]	validation_0-rmse:0.58690	validation_1-rmse:0.61023
# [807]	validation_0-rmse:0.58676	validation_1-rmse:0.61014
# [808]	validation_0-rmse:0.58666	validation_1-rmse:0.60991
# [809]	validation_0-rmse:0.58656	validation_1-rmse:0.60985
# [810]	validation_0-rmse:0.58627	validation_1-rmse:0.60948
# [811]	validation_0-rmse:0.58617	validation_1-rmse:0.60926
# [812]	validation_0-rmse:0.58604	validation_1-rmse:0.60915
# [813]	validation_0-rmse:0.58561	validation_1-rmse:0.60852
# [814]	validation_0-rmse:0.58547	validation_1-rmse:0.60844
# [815]	validation_0-rmse:0.58535	validation_1-rmse:0.60833
# [816]	validation_0-rmse:0.58527	validation_1-rmse:0.60830
# [817]	validation_0-rmse:0.58506	validation_1-rmse:0.60807
# [818]	validation_0-rmse:0.58497	validation_1-rmse:0.60784
# [819]	validation_0-rmse:0.58484	validation_1-rmse:0.60776
# [820]	validation_0-rmse:0.58441	validation_1-rmse:0.60713
# [821]	validation_0-rmse:0.58430	validation_1-rmse:0.60704
# [822]	validation_0-rmse:0.58424	validation_1-rmse:0.60702
# [823]	validation_0-rmse:0.58414	validation_1-rmse:0.60681
# [824]	validation_0-rmse:0.58400	validation_1-rmse:0.60672
# ...
# [9742]	validation_0-rmse:0.38776	validation_1-rmse:0.42547
# [9743]	validation_0-rmse:0.38776	validation_1-rmse:0.42547
# [9744]	validation_0-rmse:0.38776	validation_1-rmse:0.42547
# [9745]	validation_0-rmse:0.38776	validation_1-rmse:0.42547
# [9746]	validation_0-rmse:0.38775	validation_1-rmse:0.42547
# [9747]	validation_0-rmse:0.38775	validation_1-rmse:0.42547
# [9748]	validation_0-rmse:0.38775	validation_1-rmse:0.42547
# [9749]	validation_0-rmse:0.38775	validation_1-rmse:0.42547
# [9750]	validation_0-rmse:0.38775	validation_1-rmse:0.42547
# [9751]	validation_0-rmse:0.38775	validation_1-rmse:0.42547
# [9752]	validation_0-rmse:0.38774	validation_1-rmse:0.42547
# [9753]	validation_0-rmse:0.38774	validation_1-rmse:0.42547
# [9754]	validation_0-rmse:0.38774	validation_1-rmse:0.42546
# [9755]	validation_0-rmse:0.38773	validation_1-rmse:0.42546
# [9756]	validation_0-rmse:0.38773	validation_1-rmse:0.42546
# [9757]	validation_0-rmse:0.38773	validation_1-rmse:0.42546
# [9758]	validation_0-rmse:0.38773	validation_1-rmse:0.42546
# [9759]	validation_0-rmse:0.38773	validation_1-rmse:0.42546
# [9760]	validation_0-rmse:0.38773	validation_1-rmse:0.42546
# [9761]	validation_0-rmse:0.38772	validation_1-rmse:0.42546
# [9762]	validation_0-rmse:0.38772	validation_1-rmse:0.42546
# [9763]	validation_0-rmse:0.38772	validation_1-rmse:0.42546
# [9764]	validation_0-rmse:0.38772	validation_1-rmse:0.42546
# [9765]	validation_0-rmse:0.38772	validation_1-rmse:0.42546
# [9766]	validation_0-rmse:0.38771	validation_1-rmse:0.42546
# [9767]	validation_0-rmse:0.38771	validation_1-rmse:0.42546
# [9768]	validation_0-rmse:0.38771	validation_1-rmse:0.42545
# [9769]	validation_0-rmse:0.38771	validation_1-rmse:0.42545
# [9770]	validation_0-rmse:0.38770	validation_1-rmse:0.42545
# [9771]	validation_0-rmse:0.38770	validation_1-rmse:0.42545
# [9772]	validation_0-rmse:0.38770	validation_1-rmse:0.42545
# [9773]	validation_0-rmse:0.38769	validation_1-rmse:0.42544
# [9774]	validation_0-rmse:0.38769	validation_1-rmse:0.42544
# [9775]	validation_0-rmse:0.38769	validation_1-rmse:0.42544
# [9776]	validation_0-rmse:0.38768	validation_1-rmse:0.42544
# [9777]	validation_0-rmse:0.38768	validation_1-rmse:0.42544
# [9778]	validation_0-rmse:0.38768	validation_1-rmse:0.42544
# [9779]	validation_0-rmse:0.38768	validation_1-rmse:0.42544
# [9780]	validation_0-rmse:0.38768	validation_1-rmse:0.42544
# [9781]	validation_0-rmse:0.38767	validation_1-rmse:0.42543
# [9782]	validation_0-rmse:0.38767	validation_1-rmse:0.42543
# [9783]	validation_0-rmse:0.38766	validation_1-rmse:0.42542
# [9784]	validation_0-rmse:0.38766	validation_1-rmse:0.42542
# [9785]	validation_0-rmse:0.38766	validation_1-rmse:0.42542
# [9786]	validation_0-rmse:0.38766	validation_1-rmse:0.42542
# [9787]	validation_0-rmse:0.38766	validation_1-rmse:0.42542
# [9788]	validation_0-rmse:0.38766	validation_1-rmse:0.42541
# [9789]	validation_0-rmse:0.38765	validation_1-rmse:0.42541
# [9790]	validation_0-rmse:0.38765	validation_1-rmse:0.42541
# [9791]	validation_0-rmse:0.38765	validation_1-rmse:0.42541
# [9792]	validation_0-rmse:0.38765	validation_1-rmse:0.42541
# [9793]	validation_0-rmse:0.38765	validation_1-rmse:0.42541
# [9794]	validation_0-rmse:0.38765	validation_1-rmse:0.42539
# [9795]	validation_0-rmse:0.38765	validation_1-rmse:0.42539
# [9796]	validation_0-rmse:0.38764	validation_1-rmse:0.42539
# [9797]	validation_0-rmse:0.38764	validation_1-rmse:0.42539
# [9798]	validation_0-rmse:0.38764	validation_1-rmse:0.42539
# [9799]	validation_0-rmse:0.38763	validation_1-rmse:0.42539
# [9800]	validation_0-rmse:0.38763	validation_1-rmse:0.42539
# [9801]	validation_0-rmse:0.38762	validation_1-rmse:0.42539
# [9802]	validation_0-rmse:0.38762	validation_1-rmse:0.42539
# [9803]	validation_0-rmse:0.38762	validation_1-rmse:0.42539
# [9804]	validation_0-rmse:0.38761	validation_1-rmse:0.42539
# [9805]	validation_0-rmse:0.38761	validation_1-rmse:0.42539
# [9806]	validation_0-rmse:0.38761	validation_1-rmse:0.42539
# [9807]	validation_0-rmse:0.38760	validation_1-rmse:0.42539
# [9808]	validation_0-rmse:0.38760	validation_1-rmse:0.42539
# [9809]	validation_0-rmse:0.38760	validation_1-rmse:0.42539
# [9810]	validation_0-rmse:0.38760	validation_1-rmse:0.42539
# [9811]	validation_0-rmse:0.38760	validation_1-rmse:0.42539
# [9812]	validation_0-rmse:0.38759	validation_1-rmse:0.42539
# [9813]	validation_0-rmse:0.38759	validation_1-rmse:0.42539
# [9814]	validation_0-rmse:0.38759	validation_1-rmse:0.42539
# [9815]	validation_0-rmse:0.38758	validation_1-rmse:0.42539
# [9816]	validation_0-rmse:0.38757	validation_1-rmse:0.42538
# [9817]	validation_0-rmse:0.38757	validation_1-rmse:0.42538
# [9818]	validation_0-rmse:0.38757	validation_1-rmse:0.42538
# [9819]	validation_0-rmse:0.38757	validation_1-rmse:0.42538
# [9820]	validation_0-rmse:0.38756	validation_1-rmse:0.42538
# [9821]	validation_0-rmse:0.38756	validation_1-rmse:0.42537
# [9822]	validation_0-rmse:0.38756	validation_1-rmse:0.42538
# [9823]	validation_0-rmse:0.38755	validation_1-rmse:0.42538
# [9824]	validation_0-rmse:0.38755	validation_1-rmse:0.42538
# [9825]	validation_0-rmse:0.38755	validation_1-rmse:0.42538
# [9826]	validation_0-rmse:0.38754	validation_1-rmse:0.42538
# [9827]	validation_0-rmse:0.38754	validation_1-rmse:0.42537
# [9828]	validation_0-rmse:0.38753	validation_1-rmse:0.42537
# [9829]	validation_0-rmse:0.38753	validation_1-rmse:0.42537
# [9830]	validation_0-rmse:0.38752	validation_1-rmse:0.42537
# [9831]	validation_0-rmse:0.38752	validation_1-rmse:0.42536
# [9832]	validation_0-rmse:0.38751	validation_1-rmse:0.42536
# [9833]	validation_0-rmse:0.38750	validation_1-rmse:0.42535
# [9834]	validation_0-rmse:0.38750	validation_1-rmse:0.42535
# [9835]	validation_0-rmse:0.38749	validation_1-rmse:0.42535
# [9836]	validation_0-rmse:0.38748	validation_1-rmse:0.42535
# [9837]	validation_0-rmse:0.38748	validation_1-rmse:0.42534
# [9838]	validation_0-rmse:0.38748	validation_1-rmse:0.42534
# [9839]	validation_0-rmse:0.38747	validation_1-rmse:0.42534
# [9840]	validation_0-rmse:0.38746	validation_1-rmse:0.42533
# [9841]	validation_0-rmse:0.38746	validation_1-rmse:0.42533
# [9842]	validation_0-rmse:0.38745	validation_1-rmse:0.42533
# [9843]	validation_0-rmse:0.38745	validation_1-rmse:0.42533
# [9844]	validation_0-rmse:0.38745	validation_1-rmse:0.42533
# [9845]	validation_0-rmse:0.38744	validation_1-rmse:0.42532
# [9846]	validation_0-rmse:0.38744	validation_1-rmse:0.42533
# [9847]	validation_0-rmse:0.38743	validation_1-rmse:0.42532
# [9848]	validation_0-rmse:0.38743	validation_1-rmse:0.42533
# [9849]	validation_0-rmse:0.38743	validation_1-rmse:0.42533
# [9850]	validation_0-rmse:0.38743	validation_1-rmse:0.42533
# [9851]	validation_0-rmse:0.38742	validation_1-rmse:0.42532
# [9852]	validation_0-rmse:0.38742	validation_1-rmse:0.42532
# [9853]	validation_0-rmse:0.38741	validation_1-rmse:0.42532
# [9854]	validation_0-rmse:0.38741	validation_1-rmse:0.42532
# [9855]	validation_0-rmse:0.38741	validation_1-rmse:0.42532
# [9856]	validation_0-rmse:0.38741	validation_1-rmse:0.42532
# [9857]	validation_0-rmse:0.38740	validation_1-rmse:0.42532
# [9858]	validation_0-rmse:0.38740	validation_1-rmse:0.42531
# [9859]	validation_0-rmse:0.38740	validation_1-rmse:0.42531
# [9860]	validation_0-rmse:0.38739	validation_1-rmse:0.42531
# [9861]	validation_0-rmse:0.38739	validation_1-rmse:0.42531
# [9862]	validation_0-rmse:0.38739	validation_1-rmse:0.42531
# [9863]	validation_0-rmse:0.38739	validation_1-rmse:0.42531
# [9864]	validation_0-rmse:0.38738	validation_1-rmse:0.42530
# [9865]	validation_0-rmse:0.38738	validation_1-rmse:0.42530
# [9866]	validation_0-rmse:0.38738	validation_1-rmse:0.42530
# [9867]	validation_0-rmse:0.38738	validation_1-rmse:0.42530
# [9868]	validation_0-rmse:0.38738	validation_1-rmse:0.42530
# [9869]	validation_0-rmse:0.38738	validation_1-rmse:0.42530
# [9870]	validation_0-rmse:0.38738	validation_1-rmse:0.42530
# [9871]	validation_0-rmse:0.38738	validation_1-rmse:0.42530
# [9872]	validation_0-rmse:0.38738	validation_1-rmse:0.42530
# [9873]	validation_0-rmse:0.38737	validation_1-rmse:0.42530
# [9874]	validation_0-rmse:0.38737	validation_1-rmse:0.42530
# [9875]	validation_0-rmse:0.38737	validation_1-rmse:0.42530
# [9876]	validation_0-rmse:0.38736	validation_1-rmse:0.42530
# [9877]	validation_0-rmse:0.38736	validation_1-rmse:0.42530
# [9878]	validation_0-rmse:0.38736	validation_1-rmse:0.42530
# [9879]	validation_0-rmse:0.38736	validation_1-rmse:0.42530
# [9880]	validation_0-rmse:0.38736	validation_1-rmse:0.42530
# [9881]	validation_0-rmse:0.38736	validation_1-rmse:0.42530
# [9882]	validation_0-rmse:0.38735	validation_1-rmse:0.42530
# [9883]	validation_0-rmse:0.38735	validation_1-rmse:0.42530
# [9884]	validation_0-rmse:0.38735	validation_1-rmse:0.42530
# [9885]	validation_0-rmse:0.38735	validation_1-rmse:0.42530
# [9886]	validation_0-rmse:0.38735	validation_1-rmse:0.42530
# [9887]	validation_0-rmse:0.38734	validation_1-rmse:0.42530
# [9888]	validation_0-rmse:0.38734	validation_1-rmse:0.42530
# [9889]	validation_0-rmse:0.38734	validation_1-rmse:0.42530
# [9890]	validation_0-rmse:0.38734	validation_1-rmse:0.42530
# [9891]	validation_0-rmse:0.38734	validation_1-rmse:0.42529
# [9892]	validation_0-rmse:0.38733	validation_1-rmse:0.42529
# [9893]	validation_0-rmse:0.38733	validation_1-rmse:0.42529
# [9894]	validation_0-rmse:0.38733	validation_1-rmse:0.42529
# [9895]	validation_0-rmse:0.38733	validation_1-rmse:0.42529
# [9896]	validation_0-rmse:0.38733	validation_1-rmse:0.42529
# [9897]	validation_0-rmse:0.38732	validation_1-rmse:0.42529
# [9898]	validation_0-rmse:0.38732	validation_1-rmse:0.42529
# [9899]	validation_0-rmse:0.38732	validation_1-rmse:0.42529
# [9900]	validation_0-rmse:0.38731	validation_1-rmse:0.42529
# [9901]	validation_0-rmse:0.38731	validation_1-rmse:0.42528
# [9902]	validation_0-rmse:0.38730	validation_1-rmse:0.42528
# [9903]	validation_0-rmse:0.38730	validation_1-rmse:0.42528
# [9904]	validation_0-rmse:0.38730	validation_1-rmse:0.42528
# [9905]	validation_0-rmse:0.38729	validation_1-rmse:0.42528
# [9906]	validation_0-rmse:0.38729	validation_1-rmse:0.42528
# [9907]	validation_0-rmse:0.38728	validation_1-rmse:0.42527
# [9908]	validation_0-rmse:0.38728	validation_1-rmse:0.42527
# [9909]	validation_0-rmse:0.38728	validation_1-rmse:0.42527
# [9910]	validation_0-rmse:0.38727	validation_1-rmse:0.42527
# [9911]	validation_0-rmse:0.38727	validation_1-rmse:0.42526
# [9912]	validation_0-rmse:0.38726	validation_1-rmse:0.42526
# [9913]	validation_0-rmse:0.38726	validation_1-rmse:0.42526
# [9914]	validation_0-rmse:0.38725	validation_1-rmse:0.42527
# [9915]	validation_0-rmse:0.38725	validation_1-rmse:0.42527
# [9916]	validation_0-rmse:0.38725	validation_1-rmse:0.42527
# [9917]	validation_0-rmse:0.38725	validation_1-rmse:0.42527
# [9918]	validation_0-rmse:0.38724	validation_1-rmse:0.42527
# [9919]	validation_0-rmse:0.38724	validation_1-rmse:0.42526
# [9920]	validation_0-rmse:0.38724	validation_1-rmse:0.42525
# [9921]	validation_0-rmse:0.38723	validation_1-rmse:0.42525
# [9922]	validation_0-rmse:0.38723	validation_1-rmse:0.42525
# [9923]	validation_0-rmse:0.38722	validation_1-rmse:0.42524
# [9924]	validation_0-rmse:0.38722	validation_1-rmse:0.42524
# [9925]	validation_0-rmse:0.38721	validation_1-rmse:0.42524
# [9926]	validation_0-rmse:0.38721	validation_1-rmse:0.42524
# [9927]	validation_0-rmse:0.38720	validation_1-rmse:0.42523
# [9928]	validation_0-rmse:0.38720	validation_1-rmse:0.42523
# [9929]	validation_0-rmse:0.38720	validation_1-rmse:0.42523
# [9930]	validation_0-rmse:0.38719	validation_1-rmse:0.42523
# [9931]	validation_0-rmse:0.38719	validation_1-rmse:0.42522
# [9932]	validation_0-rmse:0.38718	validation_1-rmse:0.42522
# [9933]	validation_0-rmse:0.38718	validation_1-rmse:0.42522
# [9934]	validation_0-rmse:0.38717	validation_1-rmse:0.42522
# [9935]	validation_0-rmse:0.38717	validation_1-rmse:0.42522
# [9936]	validation_0-rmse:0.38716	validation_1-rmse:0.42522
# [9937]	validation_0-rmse:0.38716	validation_1-rmse:0.42522
# [9938]	validation_0-rmse:0.38716	validation_1-rmse:0.42521
# [9939]	validation_0-rmse:0.38715	validation_1-rmse:0.42522
# [9940]	validation_0-rmse:0.38715	validation_1-rmse:0.42522
# [9941]	validation_0-rmse:0.38714	validation_1-rmse:0.42521
# [9942]	validation_0-rmse:0.38714	validation_1-rmse:0.42521
# [9943]	validation_0-rmse:0.38713	validation_1-rmse:0.42521
# [9944]	validation_0-rmse:0.38713	validation_1-rmse:0.42520
# [9945]	validation_0-rmse:0.38713	validation_1-rmse:0.42521
# [9946]	validation_0-rmse:0.38712	validation_1-rmse:0.42521
# [9947]	validation_0-rmse:0.38712	validation_1-rmse:0.42521
# [9948]	validation_0-rmse:0.38712	validation_1-rmse:0.42521
# [9949]	validation_0-rmse:0.38712	validation_1-rmse:0.42520
# [9950]	validation_0-rmse:0.38712	validation_1-rmse:0.42520
# [9951]	validation_0-rmse:0.38711	validation_1-rmse:0.42520
# [9952]	validation_0-rmse:0.38711	validation_1-rmse:0.42520
# [9953]	validation_0-rmse:0.38710	validation_1-rmse:0.42520
# [9954]	validation_0-rmse:0.38710	validation_1-rmse:0.42520
# [9955]	validation_0-rmse:0.38710	validation_1-rmse:0.42520
# [9956]	validation_0-rmse:0.38709	validation_1-rmse:0.42520
# [9957]	validation_0-rmse:0.38709	validation_1-rmse:0.42520
# [9958]	validation_0-rmse:0.38709	validation_1-rmse:0.42520
# [9959]	validation_0-rmse:0.38709	validation_1-rmse:0.42520
# [9960]	validation_0-rmse:0.38708	validation_1-rmse:0.42520
# [9961]	validation_0-rmse:0.38708	validation_1-rmse:0.42520
# [9962]	validation_0-rmse:0.38708	validation_1-rmse:0.42520
# [9963]	validation_0-rmse:0.38708	validation_1-rmse:0.42520
# [9964]	validation_0-rmse:0.38707	validation_1-rmse:0.42520
# [9965]	validation_0-rmse:0.38707	validation_1-rmse:0.42520
# [9966]	validation_0-rmse:0.38706	validation_1-rmse:0.42520
# [9967]	validation_0-rmse:0.38706	validation_1-rmse:0.42520
# [9968]	validation_0-rmse:0.38706	validation_1-rmse:0.42520
# [9969]	validation_0-rmse:0.38706	validation_1-rmse:0.42520
# [9970]	validation_0-rmse:0.38705	validation_1-rmse:0.42520
# [9971]	validation_0-rmse:0.38705	validation_1-rmse:0.42519
# [9972]	validation_0-rmse:0.38704	validation_1-rmse:0.42519
# [9973]	validation_0-rmse:0.38704	validation_1-rmse:0.42519
# [9974]	validation_0-rmse:0.38704	validation_1-rmse:0.42519
# [9975]	validation_0-rmse:0.38703	validation_1-rmse:0.42519
# [9976]	validation_0-rmse:0.38703	validation_1-rmse:0.42519
# [9977]	validation_0-rmse:0.38703	validation_1-rmse:0.42519
# [9978]	validation_0-rmse:0.38703	validation_1-rmse:0.42519
# [9979]	validation_0-rmse:0.38702	validation_1-rmse:0.42519
# [9980]	validation_0-rmse:0.38702	validation_1-rmse:0.42519
# [9981]	validation_0-rmse:0.38702	validation_1-rmse:0.42519
# [9982]	validation_0-rmse:0.38702	validation_1-rmse:0.42519
# [9983]	validation_0-rmse:0.38702	validation_1-rmse:0.42519
# [9984]	validation_0-rmse:0.38701	validation_1-rmse:0.42519
# [9985]	validation_0-rmse:0.38701	validation_1-rmse:0.42519
# [9986]	validation_0-rmse:0.38701	validation_1-rmse:0.42518
# [9987]	validation_0-rmse:0.38700	validation_1-rmse:0.42518
# [9988]	validation_0-rmse:0.38700	validation_1-rmse:0.42518
# [9989]	validation_0-rmse:0.38699	validation_1-rmse:0.42518
# [9990]	validation_0-rmse:0.38699	validation_1-rmse:0.42518
# [9991]	validation_0-rmse:0.38699	validation_1-rmse:0.42518
# [9992]	validation_0-rmse:0.38699	validation_1-rmse:0.42518
# [9993]	validation_0-rmse:0.38698	validation_1-rmse:0.42518
# [9994]	validation_0-rmse:0.38698	validation_1-rmse:0.42518
# [9995]	validation_0-rmse:0.38698	validation_1-rmse:0.42518
# [9996]	validation_0-rmse:0.38697	validation_1-rmse:0.42518
# [9997]	validation_0-rmse:0.38697	validation_1-rmse:0.42518
# [9998]	validation_0-rmse:0.38697	validation_1-rmse:0.42518
# [9999]	validation_0-rmse:0.38697	validation_1-rmse:0.42517
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=1000,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=10000, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
# Out:
# 1407.029449014469

# %% [markdown]
# ## Generating Predictions

# %%
#Predict test set
y_pre_xgbr = xgbr.predict(X_test)

# %%
#Sales must >= 0
y_pre_xgbr = np.expm1(y_pre_xgbr)
for i in range(len(y_pre_xgbr)):
    if y_pre_xgbr[i] < 0:
        y_pre_xgbr[i] =0

# %%
df_describe = pd.DataFrame(y_pre_xgbr)
df_describe.describe()
# Out:
#                   0
# count  28512.000000
# mean     443.433350
# std     1211.659546
# min        0.000000
# 25%        3.790989
# 50%       26.406571
# 75%      246.253918
# max    15947.441406

# %%
#Create the outcome file for the competition
outcome = pd.DataFrame()
outcome["id"] = df_test.iloc[:,0]
outcome["sales"] = y_pre_xgbr
outcome
# Out:
#             id        sales
# 0      3000888     3.645138
# 1      3000889     0.043675
# 2      3000890     5.400712
# 3      3000891  2319.460205
# 4      3000892     0.282364
# ...        ...          ...
# 28507  3029395   325.171143
# 28508  3029396    95.761658
# 28509  3029397  1307.159302
# 28510  3029398    60.517803
# 28511  3029399    12.739240
#
# [28512 rows x 2 columns]

# %%
outcome.to_csv('Sales_predict.csv', index=False)

# %%
fi = pd.DataFrame(data = xgbr.feature_importances_, index = xgbr.feature_names_in_,columns=["importance"])
fi.sort_values("importance").plot(kind="barh", title="Feature Impotance")
plt.show()
